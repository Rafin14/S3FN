# %%
import numpy as np
import tensorflow as tf
import torch
from tensorflow.keras.models import load_model
from tensorflow.keras import Model, layers, Input
from sklearn.preprocessing import LabelEncoder

# %%
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=1))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
physical_devices = tf.config.experimental.list_physical_devices('GPU')

print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_4092\1195741882.py:4: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
# Load pretrained CNN model
pretrained_model = load_model("best_model_blueberry_new.h5")

pretrained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 227, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 113, 32)  0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 111, 64)   55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 109, 128)  221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 54, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 172800)            0
#
#  dense (Dense)               (None, 128)               22118528
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 22,404,482
# Trainable params: 22,404,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load label embeddings
word_embeddings = np.load("Blueberry_Embeddings.npy", allow_pickle=True).item()  # Dictionary with keys

# Extract embeddings and stack into a 2D array
word_embeddings = np.stack([word_embeddings['Good blueberries'].numpy(), 
                                   word_embeddings['Bad blueberries'].numpy()])  # Convert tensors to numpy arrays

# Ensure word_embeddings is a Tensor
word_embeddings_tensor = tf.convert_to_tensor(word_embeddings, dtype=tf.float32)

# %%
'''
# Freeze the pretrained layers
for layer in pretrained_model.layers:
    
    layer.trainable = False

# Get the third-last layer's output
second_last_layer_output = pretrained_model.get_layer(index = -4).output  # Shape: (None, 128)

# Define a new trainable dense layer with 1024 neurons
dense_layer = layers.Dense(1024, activation = 'relu', name="trainable_dense_layer")(second_last_layer_output)  # Shape: (None, 1024)

# Normalize the dense layer output and word embeddings tensor
dense_layer_norm = tf.nn.l2_normalize(dense_layer, axis=1)  # Normalize along the last dimension
word_embeddings_norm = tf.nn.l2_normalize(word_embeddings_tensor, axis=1)

# Compute the dot product with word embeddings
#dot_product = tf.matmul(dense_layer, tf.transpose(word_embeddings_tensor))  # Shape: (None, 2)
dot_product = tf.matmul(dense_layer_norm, tf.transpose(word_embeddings_norm))  # Shape: (None, 2)

# Apply softmax activation to get predictions
predictions = layers.Softmax(name="softmax_predictions")(dot_product)
'''
# Out:
# '\n# Freeze the pretrained layers\nfor layer in pretrained_model.layers:\n    \n    layer.trainable = False\n\n# Get the third-last layer\'s output\nsecond_last_layer_output = pretrained_model.get_layer(index = -4).output  # Shape: (None, 128)\n\n# Define a new trainable dense layer with 1024 neurons\ndense_layer = layers.Dense(1024, activation = \'relu\', name="trainable_dense_layer")(second_last_layer_output)  # Shape: (None, 1024)\n\n# Normalize the dense layer output and word embeddings tensor\ndense_layer_norm = tf.nn.l2_normalize(dense_layer, axis=1)  # Normalize along the last dimension\nword_embeddings_norm = tf.nn.l2_normalize(word_embeddings_tensor, axis=1)\n\n# Compute the dot product with word embeddings\n#dot_product = tf.matmul(dense_layer, tf.transpose(word_embeddings_tensor))  # Shape: (None, 2)\ndot_product = tf.matmul(dense_layer_norm, tf.transpose(word_embeddings_norm))  # Shape: (None, 2)\n\n# Apply softmax activation to get predictions\npredictions = layers.Softmax(name="softmax_predictions")(dot_product)\n'

# %%
# Freeze some pretrained layers
for layer in pretrained_model.layers:
    layer.trainable = False

# Extract image embeddings
Image_embeddings = pretrained_model.get_layer(index=-5).output

# Define a new intermediate dense layer with 512 neurons and ReLU activation
intermediate_layer = layers.Dense(
    256,
    activation='relu',
    kernel_regularizer=tf.keras.regularizers.l2(0.001),
    name="intermediate_dense_layer"
)(Image_embeddings)

# Define the trainable dense layer with 1024 neurons
dense_layer = layers.Dense(
    1024,
    activation='relu',
    kernel_regularizer=tf.keras.regularizers.l2(0.001),
    name="trainable_dense_layer"
)(intermediate_layer)

# Apply Batch Normalization and Dropout
dense_layer = layers.BatchNormalization()(dense_layer)
dense_layer = layers.Dropout(0.5)(dense_layer)

# Normalize the dense layer output and word embeddings tensor
dense_layer_norm = tf.nn.l2_normalize(dense_layer, axis=1)  # Normalize along the last dimension
word_embeddings_norm = tf.nn.l2_normalize(word_embeddings_tensor, axis=1)

# Compute the dot product with word embeddings
#dot_product = tf.matmul(dense_layer, tf.transpose(word_embeddings_tensor))  # Shape: (None, 2)
dot_product = tf.matmul(dense_layer_norm, tf.transpose(word_embeddings_norm))  # Shape: (None, 2)

# Compute the dot product with word embeddings
#dot_product = tf.matmul(dense_layer, tf.transpose(word_embeddings_tensor))

# Apply softmax activation to get predictions
predictions = layers.Softmax(name="softmax_predictions")(dot_product)

# %%
# Define the new model
new_model = Model(inputs=pretrained_model.input, outputs=predictions)

# Compile the model for training
new_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_input (InputLayer)   [(None, 32, 32, 229, 1)]  0
#
#  conv3d (Conv3D)             (None, 30, 30, 227, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 113, 32)  0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 111, 64)   55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 109, 128)  221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 54, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 172800)            0
#
#  intermediate_dense_layer (D  (None, 256)              44237056
#  ense)
#
#  trainable_dense_layer (Dens  (None, 1024)             263168
#  e)
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  tf.math.l2_normalize (TFOpL  (None, 1024)             0
#  ambda)
#
#  tf.linalg.matmul (TFOpLambd  (None, 2)                0
#  a)
#
#  softmax_predictions (Softma  (None, 2)                0
#  x)
#
# =================================================================
# Total params: 44,781,888
# Trainable params: 44,502,272
# Non-trainable params: 279,616
# _________________________________________________________________

# %%
# Load PCA data and labels
data_train = np.load('data_train_PCA.npy')  # Assuming shape (n_samples, 32 * 32 * 199)
data_test = np.load('data_test_PCA.npy')

train_labels = np.load('train_labels.npy', allow_pickle=True)  # Labels in integer format
test_labels = np.load('test_labels.npy', allow_pickle=True)

print(data_train.shape, data_test.shape, train_labels.shape, test_labels.shape )
# Out:
# (1604, 32, 32, 229) (535, 32, 32, 229) (1604,) (535,)

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
'''
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
'''
# Out:
# '\n# Add channel dimension to data\ndata_train = data_train[..., np.newaxis]\ndata_test = data_test[..., np.newaxis]\n\ndata_train.shape, data_test.shape\n'

# %%
print(np.unique(train_labels))
print(np.unique(y_train))
# Out:
# ['Bad_Blueberries' 'Good_Blueberries']
# [0 1]

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 4

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='Blueberry_Fused_new2.h5',         # Path to save the best model
    monitor='val_accuracy',                       # Metric to monitor
    save_best_only=True,                      # Save only the best model
    save_weights_only=False,                  # Save the entire model (architecture + weights)
    mode='max',                               # Mode 'min' because we want to minimize validation loss
    verbose=1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',                       # Metric to monitor
    patience=15,                              # Number of epochs to wait before stopping
    restore_best_weights=True                 # Restore model weights from the epoch with the best metric
)

# Train the model with the callbacks
history = new_model.fit(
    train_dataset,
    epochs=50,
    validation_data=test_dataset,
    callbacks=[checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.7618
# Epoch 1: val_accuracy improved from -inf to 0.79065, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 45s 104ms/step - loss: 0.7406 - accuracy: 0.7618 - val_loss: 0.7101 - val_accuracy: 0.7907
# Epoch 2/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.7793
# Epoch 2: val_accuracy did not improve from 0.79065
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7120 - accuracy: 0.7793 - val_loss: 0.7089 - val_accuracy: 0.7776
# Epoch 3/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7114 - accuracy: 0.7899
# Epoch 3: val_accuracy improved from 0.79065 to 0.79252, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 41s 103ms/step - loss: 0.7114 - accuracy: 0.7899 - val_loss: 0.7082 - val_accuracy: 0.7925
# Epoch 4/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7111 - accuracy: 0.7862
# Epoch 4: val_accuracy improved from 0.79252 to 0.84486, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 42s 104ms/step - loss: 0.7111 - accuracy: 0.7862 - val_loss: 0.7078 - val_accuracy: 0.8449
# Epoch 5/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.7930
# Epoch 5: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7112 - accuracy: 0.7930 - val_loss: 0.7073 - val_accuracy: 0.8168
# Epoch 6/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.8155
# Epoch 6: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 40s 101ms/step - loss: 0.7099 - accuracy: 0.8155 - val_loss: 0.7072 - val_accuracy: 0.7813
# Epoch 7/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.8030
# Epoch 7: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7100 - accuracy: 0.8030 - val_loss: 0.7072 - val_accuracy: 0.8243
# Epoch 8/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.8074
# Epoch 8: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7100 - accuracy: 0.8074 - val_loss: 0.7078 - val_accuracy: 0.8112
# Epoch 9/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7097 - accuracy: 0.8130
# Epoch 9: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7097 - accuracy: 0.8130 - val_loss: 0.7066 - val_accuracy: 0.8411
# Epoch 10/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.8173
# Epoch 10: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7095 - accuracy: 0.8173 - val_loss: 0.7076 - val_accuracy: 0.8019
# Epoch 11/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7091 - accuracy: 0.8242
# Epoch 11: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7091 - accuracy: 0.8242 - val_loss: 0.7072 - val_accuracy: 0.7869
# Epoch 12/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.8111
# Epoch 12: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7095 - accuracy: 0.8111 - val_loss: 0.7067 - val_accuracy: 0.8262
# Epoch 13/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.8198
# Epoch 13: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7092 - accuracy: 0.8198 - val_loss: 0.7066 - val_accuracy: 0.8224
# Epoch 14/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7093 - accuracy: 0.8105
# Epoch 14: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7093 - accuracy: 0.8105 - val_loss: 0.7075 - val_accuracy: 0.7832
# Epoch 15/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8248
# Epoch 15: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7086 - accuracy: 0.8248 - val_loss: 0.7062 - val_accuracy: 0.8075
# Epoch 16/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8173
# Epoch 16: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7090 - accuracy: 0.8173 - val_loss: 0.7060 - val_accuracy: 0.8224
# Epoch 17/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8317
# Epoch 17: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7086 - accuracy: 0.8317 - val_loss: 0.7054 - val_accuracy: 0.8299
# Epoch 18/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8279
# Epoch 18: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7086 - accuracy: 0.8279 - val_loss: 0.7057 - val_accuracy: 0.8355
# Epoch 19/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8298
# Epoch 19: val_accuracy did not improve from 0.84486
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7086 - accuracy: 0.8298 - val_loss: 0.7056 - val_accuracy: 0.8262
# Epoch 20/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.8192
# Epoch 20: val_accuracy improved from 0.84486 to 0.84860, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 41s 103ms/step - loss: 0.7088 - accuracy: 0.8192 - val_loss: 0.7073 - val_accuracy: 0.8486
# Epoch 21/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7083 - accuracy: 0.8404
# Epoch 21: val_accuracy did not improve from 0.84860
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7083 - accuracy: 0.8404 - val_loss: 0.7058 - val_accuracy: 0.8224
# Epoch 22/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8123
# Epoch 22: val_accuracy improved from 0.84860 to 0.85047, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 41s 103ms/step - loss: 0.7090 - accuracy: 0.8123 - val_loss: 0.7046 - val_accuracy: 0.8505
# Epoch 23/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7084 - accuracy: 0.8373
# Epoch 23: val_accuracy did not improve from 0.85047
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7084 - accuracy: 0.8373 - val_loss: 0.7054 - val_accuracy: 0.8299
# Epoch 24/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7085 - accuracy: 0.8286
# Epoch 24: val_accuracy improved from 0.85047 to 0.85421, saving model to Blueberry_Fused_new2.h5
# 401/401 [==============================] - 42s 103ms/step - loss: 0.7085 - accuracy: 0.8286 - val_loss: 0.7054 - val_accuracy: 0.8542
# Epoch 25/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.8267
# Epoch 25: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7089 - accuracy: 0.8267 - val_loss: 0.7065 - val_accuracy: 0.8093
# Epoch 26/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.8204
# Epoch 26: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7089 - accuracy: 0.8204 - val_loss: 0.7068 - val_accuracy: 0.8112
# Epoch 27/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.8223
# Epoch 27: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 102ms/step - loss: 0.7089 - accuracy: 0.8223 - val_loss: 0.7071 - val_accuracy: 0.7813
# Epoch 28/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8229
# Epoch 28: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7090 - accuracy: 0.8229 - val_loss: 0.7069 - val_accuracy: 0.8000
# Epoch 29/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7091 - accuracy: 0.8261
# Epoch 29: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7091 - accuracy: 0.8261 - val_loss: 0.7060 - val_accuracy: 0.8336
# Epoch 30/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8441
# Epoch 30: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7086 - accuracy: 0.8441 - val_loss: 0.7054 - val_accuracy: 0.8430
# Epoch 31/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.8248
# Epoch 31: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7089 - accuracy: 0.8248 - val_loss: 0.7055 - val_accuracy: 0.8299
# Epoch 32/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.8367
# Epoch 32: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7087 - accuracy: 0.8367 - val_loss: 0.7056 - val_accuracy: 0.8449
# Epoch 33/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8180
# Epoch 33: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7090 - accuracy: 0.8180 - val_loss: 0.7059 - val_accuracy: 0.8318
# Epoch 34/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.8192
# Epoch 34: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7089 - accuracy: 0.8192 - val_loss: 0.7101 - val_accuracy: 0.7009
# Epoch 35/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8292
# Epoch 35: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7090 - accuracy: 0.8292 - val_loss: 0.7059 - val_accuracy: 0.8262
# Epoch 36/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.8379
# Epoch 36: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7087 - accuracy: 0.8379 - val_loss: 0.7060 - val_accuracy: 0.8336
# Epoch 37/50
# 401/401 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.8373
# Epoch 37: val_accuracy did not improve from 0.85421
# 401/401 [==============================] - 41s 101ms/step - loss: 0.7086 - accuracy: 0.8373 - val_loss: 0.7063 - val_accuracy: 0.8243

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
merged_model = load_model("Blueberry_Fused_new.h5")

# %%
# Evaluate the model
test_loss, test_accuracy = merged_model.evaluate(test_dataset)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 134/134 [==============================] - 7s 50ms/step - loss: 0.8110 - accuracy: 0.8636
# Test Loss: 0.8110
# Test Accuracy: 0.8636

# %%
test_predictions_prob = merged_model.predict(test_dataset)
test_predictions = np.argmax(test_predictions_prob, axis=1)
# Out:
# 134/134 [==============================] - 7s 48ms/step

# %%
from sklearn.metrics import classification_report

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions, target_names=["Good_Blueberry", "Bad_Blueberry"]))
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
# Good_Blueberry       0.88      0.84      0.86       267
#  Bad_Blueberry       0.85      0.89      0.87       268
#
#       accuracy                           0.86       535
#      macro avg       0.86      0.86      0.86       535
#   weighted avg       0.86      0.86      0.86       535

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

#confusion matrix
cm = confusion_matrix(y_test, test_predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Good_Blueberry", "Bad_Blueberry"], yticklabels=["Good_Blueberry", "Bad_Blueberry"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
