# %%
import os

def print_tree(start_path, prefix=""):
    
    items = sorted(os.listdir(start_path))
    
    for i, item in enumerate(items):
        
        path = os.path.join(start_path, item)
        
        connector = "└── " if i == len(items) - 1 else "├── "
        print(prefix + connector + item)
        
        if os.path.isdir(path):
            
            extension = "    " if i == len(items) - 1 else "│   "
            print_tree(path, prefix + extension)

print_tree(".")
# Out:
# ├── Blueberry
# │   ├── 3DCNNs
# │   │   ├── 3DCNN.ipynb
# │   │   └── Random_Inference.ipynb
# │   ├── Baseline
# │   │   └── Baseline_SM_Blueberry.ipynb
# │   ├── Dataset_Code
# │   │   ├── Preprocessing_New
# │   │   │   ├── Merge_npy.ipynb
# │   │   │   ├── Preprocessing_Cubes.ipynb
# │   │   │   ├── Preprocessing_SM.ipynb
# │   │   │   └── Renaming.ipynb
# │   │   └── SM_Combine_RandomCube
# │   │       ├── Dataset_split.ipynb
# │   │       ├── PCA.ipynb
# │   │       ├── Random_Cube.ipynb
# │   │       ├── Spectral_Mean.ipynb
# │   │       └── combined_npy.ipynb
# │   ├── Embedding_Corpus
# │   │   ├── Blueberry_Label_Embeddings_Roberta.ipynb
# │   │   ├── Embedding_Individual.ipynb
# │   │   ├── GPT_Prompt.ipynb
# │   │   ├── llm_models_&_label_embedding.ipynb
# │   │   └── sentence_encoder.ipynb
# │   ├── Extract_Features
# │   │   └── Extract_Features_CNN.ipynb
# │   └── Fusion
# │       ├── Fusion_Aug_86.36.ipynb
# │       ├── Fusion_Patch_NoPCA_NoAug.ipynb
# │       └── Random_Inference.ipynb
# ├── Folder_Structure.ipynb
# ├── General
# │   ├── Dataset_Renaming.ipynb
# │   ├── HSI_Visualization.ipynb
# │   └── Spectral_Visualization.ipynb
# ├── Ripeness
# │   ├── 3DCNNs
# │   │   ├── 3DCNN_Avacado_NIR_PCA.ipynb
# │   │   ├── 3DCNN_Avacado_VIS_PCA.ipynb
# │   │   ├── 3DCNN_Kiwi_VIS_PCA.ipynb
# │   │   └── Random_Inference.ipynb
# │   ├── Baseline
# │   │   └── Baseline_SM.ipynb
# │   ├── Dataset_Code
# │   │   ├── BintoNpy_resize_split.ipynb
# │   │   ├── PCA.ipynb
# │   │   ├── Random_Cube.ipynb
# │   │   ├── Spectral_Mean.ipynb
# │   │   └── combined_npy.ipynb
# │   ├── Embedding_Corpus
# │   │   ├── Embedding_Individual.ipynb
# │   │   ├── GPT_Prompt.ipynb
# │   │   ├── Label_Embeddings_Roberta.ipynb
# │   │   ├── llm_models_&_label_embedding.ipynb
# │   │   ├── sentence_encoder copy.ipynb
# │   │   └── sentence_encoder.ipynb
# │   ├── Extract_Features
# │   │   └── Extract_Features_CNN.ipynb
# │   └── Fusion
# │       ├── Fusion_Aug.ipynb
# │       ├── Random_Inference.ipynb
# │       └── Test_w_voting.ipynb
# ├── Running_Instructions.txt
# ├── Wood
# │   ├── 3DCNNs
# │   │   ├── 3DCNN_wood.ipynb
# │   │   └── 3DCNN_wood_pca_done.ipynb
# │   ├── Baseline
# │   │   └── Baseline_SM_Wood.ipynb
# │   ├── Dataset_Codes
# │   │   ├── HSI_Specs.ipynb
# │   │   ├── Spectral_Mean_Wood.ipynb
# │   │   └── combined_npy.ipynb
# │   ├── Embedding&Corpus
# │   │   ├── Embedding_Individual.ipynb
# │   │   ├── GPT_Prompt.ipynb
# │   │   ├── Wood_Label_Embeddings_Roberta.ipynb
# │   │   ├── Word2Vec_encoder.ipynb
# │   │   ├── llm_models_&_label_embedding.ipynb
# │   │   ├── openai_encoder.ipynb
# │   │   └── sentence_encoder.ipynb
# │   └── Fusion
# │       ├── CNN&LLM
# │       │   └── Merge_w_CNN_WORKS.ipynb
# │       └── extracted_features
# │           └── Extract_Features_CNN.ipynb
# └── requirements.txt
