# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=1)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_17952\603528863.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data_train = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_VIS_PCA_train.npy', allow_pickle= True)
train_labels = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_Ripeness_VIS_train_labels.npy', allow_pickle= True)

data_val = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_VIS_PCA_val.npy', allow_pickle= True)
val_labels = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_Ripeness_VIS_val_labels.npy', allow_pickle= True)

data_test = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_VIS_PCA_test.npy', allow_pickle= True)
test_labels = np.load(r'C:\Users\rafin\Desktop\HSIC\Ripeness\Datasets\CNN_Datasets\Avacado_VIS\PCA\Avocado_Ripeness_VIS_test_labels.npy', allow_pickle= True)

data_train.shape, train_labels.shape, data_val.shape, val_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((910, 32, 32, 138),
#  (910,),
#  (140, 32, 32, 138),
#  (140,),
#  (170, 32, 32, 138),
#  (170,))

# %%
# Compute mean and std from training data (per-channel normalization)
mean = data_train.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data_train.std(axis=(0, 1, 2), keepdims=True)

# Normalize all datasets using training statistics
data_train = (data_train - mean) / std_dev
data_val = (data_val - mean) / std_dev
data_test = (data_test - mean) / std_dev

# Verify shapes
print("Shapes after normalization:")
print("Train:", data_train.shape, "Labels:", train_labels.shape)
print("Val:", data_val.shape, "Labels:", val_labels.shape)
print("Test:", data_test.shape, "Labels:", test_labels.shape)
# Out:
# Shapes after normalization:
# Train: (910, 32, 32, 138) Labels: (910,)
# Val: (140, 32, 32, 138) Labels: (140,)
# Test: (170, 32, 32, 138) Labels: (170,)

# %%
le = LabelEncoder()

y_train = le.fit_transform(train_labels)
y_val = le.transform(val_labels)
y_test = le.transform(test_labels)

print("Class mapping:", le.classes_)
# Out:
# Class mapping: ['Overripe' 'Perfect' 'Unripe']

# %%
for class_name, encoded_label in zip(le.classes_, range(len(le.classes_))):
    
    print(f"Original: '{class_name}' \t-> Encoded: {encoded_label}")

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_val = data_val[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape ,data_val.shape, data_test.shape
# Out:
# ((910, 32, 32, 138, 1), (140, 32, 32, 138, 1), (170, 32, 32, 138, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert all data to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((data_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Configure datasets
batch_size = 4

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
#tf.random.set_seed(1234)

input_shape = (32, 32, 138, 1)

model = models.Sequential([
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
  
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),

    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),

    layers.Flatten(),
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5

    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(3, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 136, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 68, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 66, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 64, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 32, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 102400)            0
#
#  dense (Dense)               (None, 128)               13107328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 13,393,347
# Trainable params: 13,393,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = '3DCNN_Avacado__VIS_PCA_model.h5',            # Path to save the best model
    monitor = 'val_accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = val_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 228/228 [==============================] - ETA: 0s - loss: 4.2931 - accuracy: 0.7769
# Epoch 1: val_accuracy improved from -inf to 0.21429, saving model to 3DCNN_Avacado__VIS_PCA_model.h5
# 228/228 [==============================] - 15s 46ms/step - loss: 4.2931 - accuracy: 0.7769 - val_loss: 2.6828 - val_accuracy: 0.2143
# Epoch 2/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.2804 - accuracy: 0.5925
# Epoch 2: val_accuracy improved from 0.21429 to 0.50000, saving model to 3DCNN_Avacado__VIS_PCA_model.h5
# 228/228 [==============================] - 10s 43ms/step - loss: 1.2803 - accuracy: 0.5912 - val_loss: 1.2348 - val_accuracy: 0.5000
# Epoch 3/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.2260 - accuracy: 0.4956
# Epoch 3: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.2262 - accuracy: 0.4945 - val_loss: 1.1733 - val_accuracy: 0.5000
# Epoch 4/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.1768 - accuracy: 0.4956
# Epoch 4: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.1771 - accuracy: 0.4945 - val_loss: 1.1405 - val_accuracy: 0.5000
# Epoch 5/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.1509 - accuracy: 0.4956
# Epoch 5: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.1514 - accuracy: 0.4945 - val_loss: 1.1199 - val_accuracy: 0.5000
# Epoch 6/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.1316 - accuracy: 0.4956
# Epoch 6: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.1321 - accuracy: 0.4945 - val_loss: 1.1041 - val_accuracy: 0.5000
# Epoch 7/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.1188 - accuracy: 0.4945
# Epoch 7: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.1187 - accuracy: 0.4945 - val_loss: 1.0920 - val_accuracy: 0.5000
# Epoch 8/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.1073 - accuracy: 0.4956
# Epoch 8: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.1079 - accuracy: 0.4945 - val_loss: 1.0838 - val_accuracy: 0.5000
# Epoch 9/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0998 - accuracy: 0.4956
# Epoch 9: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.1004 - accuracy: 0.4945 - val_loss: 1.0778 - val_accuracy: 0.5000
# Epoch 10/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0952 - accuracy: 0.4945
# Epoch 10: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0951 - accuracy: 0.4945 - val_loss: 1.0725 - val_accuracy: 0.5000
# Epoch 11/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0908 - accuracy: 0.4956
# Epoch 11: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0915 - accuracy: 0.4945 - val_loss: 1.0680 - val_accuracy: 0.5000
# Epoch 12/100
# 228/228 [==============================] - ETA: 0s - loss: 1.0853 - accuracy: 0.4945
# Epoch 12: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0853 - accuracy: 0.4945 - val_loss: 1.0656 - val_accuracy: 0.5000
# Epoch 13/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0816 - accuracy: 0.4956
# Epoch 13: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0823 - accuracy: 0.4945 - val_loss: 1.0630 - val_accuracy: 0.5000
# Epoch 14/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0795 - accuracy: 0.4956
# Epoch 14: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0803 - accuracy: 0.4945 - val_loss: 1.0611 - val_accuracy: 0.5000
# Epoch 15/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0774 - accuracy: 0.4956
# Epoch 15: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0781 - accuracy: 0.4945 - val_loss: 1.0596 - val_accuracy: 0.5000
# Epoch 16/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0751 - accuracy: 0.4956
# Epoch 16: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0759 - accuracy: 0.4945 - val_loss: 1.0586 - val_accuracy: 0.5000
# Epoch 17/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0759 - accuracy: 0.4945
# Epoch 17: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0759 - accuracy: 0.4945 - val_loss: 1.0574 - val_accuracy: 0.5000
# Epoch 18/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0739 - accuracy: 0.4945
# Epoch 18: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0738 - accuracy: 0.4945 - val_loss: 1.0564 - val_accuracy: 0.5000
# Epoch 19/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0721 - accuracy: 0.4956
# Epoch 19: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0729 - accuracy: 0.4945 - val_loss: 1.0552 - val_accuracy: 0.5000
# Epoch 20/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0718 - accuracy: 0.4956
# Epoch 20: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0725 - accuracy: 0.4945 - val_loss: 1.0536 - val_accuracy: 0.5000
# Epoch 21/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0692 - accuracy: 0.4956
# Epoch 21: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0699 - accuracy: 0.4945 - val_loss: 1.0529 - val_accuracy: 0.5000
# Epoch 22/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0684 - accuracy: 0.4956
# Epoch 22: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0691 - accuracy: 0.4945 - val_loss: 1.0518 - val_accuracy: 0.5000
# Epoch 23/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0671 - accuracy: 0.4956
# Epoch 23: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0679 - accuracy: 0.4945 - val_loss: 1.0508 - val_accuracy: 0.5000
# Epoch 24/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0668 - accuracy: 0.4956
# Epoch 24: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0676 - accuracy: 0.4945 - val_loss: 1.0497 - val_accuracy: 0.5000
# Epoch 25/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0655 - accuracy: 0.4945
# Epoch 25: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0655 - accuracy: 0.4945 - val_loss: 1.0485 - val_accuracy: 0.5000
# Epoch 26/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0634 - accuracy: 0.4945
# Epoch 26: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0634 - accuracy: 0.4945 - val_loss: 1.0471 - val_accuracy: 0.5000
# Epoch 27/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0626 - accuracy: 0.4945
# Epoch 27: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0626 - accuracy: 0.4945 - val_loss: 1.0459 - val_accuracy: 0.5000
# Epoch 28/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0621 - accuracy: 0.4945
# Epoch 28: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0622 - accuracy: 0.4945 - val_loss: 1.0444 - val_accuracy: 0.5000
# Epoch 29/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0594 - accuracy: 0.4956
# Epoch 29: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0603 - accuracy: 0.4945 - val_loss: 1.0430 - val_accuracy: 0.5000
# Epoch 30/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0559 - accuracy: 0.4956
# Epoch 30: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0568 - accuracy: 0.4945 - val_loss: 1.0421 - val_accuracy: 0.5000
# Epoch 31/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0551 - accuracy: 0.4956
# Epoch 31: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0560 - accuracy: 0.4945 - val_loss: 1.0413 - val_accuracy: 0.5000
# Epoch 32/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0546 - accuracy: 0.4956
# Epoch 32: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0555 - accuracy: 0.4945 - val_loss: 1.0405 - val_accuracy: 0.5000
# Epoch 33/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0538 - accuracy: 0.4945
# Epoch 33: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0538 - accuracy: 0.4945 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 34/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0523 - accuracy: 0.4945
# Epoch 34: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0524 - accuracy: 0.4945 - val_loss: 1.0391 - val_accuracy: 0.5000
# Epoch 35/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0505 - accuracy: 0.4956
# Epoch 35: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0515 - accuracy: 0.4945 - val_loss: 1.0384 - val_accuracy: 0.5000
# Epoch 36/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0497 - accuracy: 0.4956
# Epoch 36: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0506 - accuracy: 0.4945 - val_loss: 1.0381 - val_accuracy: 0.5000
# Epoch 37/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0486 - accuracy: 0.4956
# Epoch 37: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0496 - accuracy: 0.4945 - val_loss: 1.0377 - val_accuracy: 0.5000
# Epoch 38/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0482 - accuracy: 0.4956
# Epoch 38: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0492 - accuracy: 0.4945 - val_loss: 1.0374 - val_accuracy: 0.5000
# Epoch 39/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0481 - accuracy: 0.4956
# Epoch 39: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0490 - accuracy: 0.4945 - val_loss: 1.0371 - val_accuracy: 0.5000
# Epoch 40/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0473 - accuracy: 0.4956
# Epoch 40: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0483 - accuracy: 0.4945 - val_loss: 1.0368 - val_accuracy: 0.5000
# Epoch 41/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0470 - accuracy: 0.4956
# Epoch 41: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0481 - accuracy: 0.4945 - val_loss: 1.0366 - val_accuracy: 0.5000
# Epoch 42/100
# 228/228 [==============================] - ETA: 0s - loss: 1.0469 - accuracy: 0.4945
# Epoch 42: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0469 - accuracy: 0.4945 - val_loss: 1.0364 - val_accuracy: 0.5000
# Epoch 43/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0472 - accuracy: 0.4945
# Epoch 43: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0473 - accuracy: 0.4945 - val_loss: 1.0363 - val_accuracy: 0.5000
# Epoch 44/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0453 - accuracy: 0.4956
# Epoch 44: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0464 - accuracy: 0.4945 - val_loss: 1.0362 - val_accuracy: 0.5000
# Epoch 45/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0453 - accuracy: 0.4956
# Epoch 45: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0463 - accuracy: 0.4945 - val_loss: 1.0361 - val_accuracy: 0.5000
# Epoch 46/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0455 - accuracy: 0.4956
# Epoch 46: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0465 - accuracy: 0.4945 - val_loss: 1.0359 - val_accuracy: 0.5000
# Epoch 47/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0448 - accuracy: 0.4956
# Epoch 47: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0458 - accuracy: 0.4945 - val_loss: 1.0358 - val_accuracy: 0.5000
# Epoch 48/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0448 - accuracy: 0.4956
# Epoch 48: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0459 - accuracy: 0.4945 - val_loss: 1.0357 - val_accuracy: 0.5000
# Epoch 49/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0451 - accuracy: 0.4945
# Epoch 49: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0452 - accuracy: 0.4945 - val_loss: 1.0356 - val_accuracy: 0.5000
# Epoch 50/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0439 - accuracy: 0.4956
# Epoch 50: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0450 - accuracy: 0.4945 - val_loss: 1.0355 - val_accuracy: 0.5000
# Epoch 51/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0446 - accuracy: 0.4945
# Epoch 51: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0448 - accuracy: 0.4945 - val_loss: 1.0354 - val_accuracy: 0.5000
# Epoch 52/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0442 - accuracy: 0.4945
# Epoch 52: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0444 - accuracy: 0.4945 - val_loss: 1.0354 - val_accuracy: 0.5000
# Epoch 53/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0441 - accuracy: 0.4956
# Epoch 53: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0452 - accuracy: 0.4945 - val_loss: 1.0353 - val_accuracy: 0.5000
# Epoch 54/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0433 - accuracy: 0.4956
# Epoch 54: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0444 - accuracy: 0.4945 - val_loss: 1.0352 - val_accuracy: 0.5000
# Epoch 55/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0442 - accuracy: 0.4945
# Epoch 55: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0352 - val_accuracy: 0.5000
# Epoch 56/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0434 - accuracy: 0.4956
# Epoch 56: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0445 - accuracy: 0.4945 - val_loss: 1.0352 - val_accuracy: 0.5000
# Epoch 57/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0430 - accuracy: 0.4956
# Epoch 57: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 44ms/step - loss: 1.0441 - accuracy: 0.4945 - val_loss: 1.0351 - val_accuracy: 0.5000
# Epoch 58/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0434 - accuracy: 0.4956
# Epoch 58: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0445 - accuracy: 0.4945 - val_loss: 1.0351 - val_accuracy: 0.5000
# Epoch 59/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0437 - accuracy: 0.4956
# Epoch 59: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0447 - accuracy: 0.4945 - val_loss: 1.0350 - val_accuracy: 0.5000
# Epoch 60/100
# 228/228 [==============================] - ETA: 0s - loss: 1.0443 - accuracy: 0.4945
# Epoch 60: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0350 - val_accuracy: 0.5000
# Epoch 61/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0441 - accuracy: 0.4945
# Epoch 61: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0350 - val_accuracy: 0.5000
# Epoch 62/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.4956
# Epoch 62: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0441 - accuracy: 0.4945 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 63/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0441 - accuracy: 0.4945
# Epoch 63: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 64/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.4956
# Epoch 64: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 65/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0439 - accuracy: 0.4945
# Epoch 65: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 66/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0433 - accuracy: 0.4956
# Epoch 66: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 67/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0432 - accuracy: 0.4956
# Epoch 67: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 68/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0426 - accuracy: 0.4956
# Epoch 68: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0436 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 69/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 69: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 70/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0430 - accuracy: 0.4956
# Epoch 70: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.0441 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 71/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 71: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0348 - val_accuracy: 0.5000
# Epoch 72/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.4956
# Epoch 72: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 73/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0427 - accuracy: 0.4956
# Epoch 73: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 74/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 74: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 75/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0441 - accuracy: 0.4945
# Epoch 75: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 76/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 76: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 77/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0439 - accuracy: 0.4945
# Epoch 77: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 78/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0440 - accuracy: 0.4945
# Epoch 78: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 79/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0430 - accuracy: 0.4956
# Epoch 79: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0441 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 80/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 80: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 81/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.4956
# Epoch 81: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 82/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0435 - accuracy: 0.4945
# Epoch 82: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 43ms/step - loss: 1.0436 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 83/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 83: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 84/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0437 - accuracy: 0.4945
# Epoch 84: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 85/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0427 - accuracy: 0.4956
# Epoch 85: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 86/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0427 - accuracy: 0.4956
# Epoch 86: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 87/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 87: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 88/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0426 - accuracy: 0.4956
# Epoch 88: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0436 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 89/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 89: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 90/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0442 - accuracy: 0.4945
# Epoch 90: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0443 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 91/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0427 - accuracy: 0.4956
# Epoch 91: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 92/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.4956
# Epoch 92: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 93/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.4956
# Epoch 93: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.0442 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 94/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0438 - accuracy: 0.4945
# Epoch 94: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 95/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0433 - accuracy: 0.4956
# Epoch 95: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0441 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 96/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 96: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 97/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 97: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0439 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 98/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 98: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 99/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0438 - accuracy: 0.4945
# Epoch 99: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 10s 42ms/step - loss: 1.0440 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 100/100
# 227/228 [============================>.] - ETA: 0s - loss: 1.0428 - accuracy: 0.4956
# Epoch 100: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 9s 41ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0347 - val_accuracy: 0.5000

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 43/43 [==============================] - 1s 12ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        50
#            1       0.47      1.00      0.64        80
#            2       0.00      0.00      0.00        40
#
#     accuracy                           0.47       170
#    macro avg       0.16      0.33      0.21       170
# weighted avg       0.22      0.47      0.30       170
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(3)], yticklabels=[str(i) for i in range(3)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
