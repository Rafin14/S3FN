# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=1)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_13324\603528863.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data_train = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_NIR_PCA_train.npy', allow_pickle= True)
train_labels = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_Ripeness_NIR_train_labels.npy', allow_pickle= True)

data_val = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_NIR_PCA_val.npy', allow_pickle= True)
val_labels = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_Ripeness_NIR_val_labels.npy', allow_pickle= True)

data_test = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_NIR_PCA_test.npy', allow_pickle= True)
test_labels = np.load('C:/Users/rafin/Desktop/HSIC/Ripeness/Datasets/CNN_Datasets/Avacado_NIR/PCA/Avocado_Ripeness_NIR_test_labels.npy', allow_pickle= True)

data_train.shape, train_labels.shape, data_val.shape, val_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((430, 32, 32, 23), (430,), (70, 32, 32, 23), (70,), (80, 32, 32, 23), (80,))

# %%
# Compute mean and std from training data (per-channel normalization)
mean = data_train.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data_train.std(axis=(0, 1, 2), keepdims=True)

# Normalize all datasets using training statistics
data_train = (data_train - mean) / std_dev
data_val = (data_val - mean) / std_dev
data_test = (data_test - mean) / std_dev

# Verify shapes
print("Shapes after normalization:")
print("Train:", data_train.shape, "Labels:", train_labels.shape)
print("Val:", data_val.shape, "Labels:", val_labels.shape)
print("Test:", data_test.shape, "Labels:", test_labels.shape)
# Out:
# Shapes after normalization:
# Train: (430, 32, 32, 23) Labels: (430,)
# Val: (70, 32, 32, 23) Labels: (70,)
# Test: (80, 32, 32, 23) Labels: (80,)

# %%
le = LabelEncoder()

y_train = le.fit_transform(train_labels)
y_val = le.transform(val_labels)
y_test = le.transform(test_labels)

print("Class mapping:", le.classes_)
# Out:
# Class mapping: ['Overripe' 'Perfect' 'Unripe']

# %%
for class_name, encoded_label in zip(le.classes_, range(len(le.classes_))):
    
    print(f"Original: '{class_name}' \t-> Encoded: {encoded_label}")
# Out:
# Original: 'Overripe' 	-> Encoded: 0
# Original: 'Perfect' 	-> Encoded: 1
# Original: 'Unripe' 	-> Encoded: 2

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_val = data_val[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape ,data_val.shape, data_test.shape
# Out:
# ((430, 32, 32, 23, 1), (70, 32, 32, 23, 1), (80, 32, 32, 23, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert all data to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((data_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Configure datasets
batch_size = 4

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
#tf.random.set_seed(1234)

input_shape = (32, 32, 23, 1)

model = models.Sequential([
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
  
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),

    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),

    layers.Flatten(),
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5

    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(3, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 21, 32)    896
#
#  average_pooling3d (AverageP  (None, 15, 15, 10, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 8, 64)     55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 6, 128)    221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 3, 128)     0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 9600)              0
#
#  dense (Dense)               (None, 128)               1228928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,514,947
# Trainable params: 1,514,947
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = '3DCNN_Avacado_PCA_model.h5',            # Path to save the best model
    monitor = 'val_accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = val_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 108/108 [==============================] - ETA: 0s - loss: 1.4538 - accuracy: 0.5791
# Epoch 1: val_accuracy improved from -inf to 0.28571, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 7s 12ms/step - loss: 1.4538 - accuracy: 0.5791 - val_loss: 1.8048 - val_accuracy: 0.2857
# Epoch 2/100
# 104/108 [===========================>..] - ETA: 0s - loss: 1.1661 - accuracy: 0.5168
# Epoch 2: val_accuracy did not improve from 0.28571
# 108/108 [==============================] - 1s 10ms/step - loss: 1.1553 - accuracy: 0.5256 - val_loss: 1.4921 - val_accuracy: 0.2857
# Epoch 3/100
# 102/108 [===========================>..] - ETA: 0s - loss: 1.1643 - accuracy: 0.5000
# Epoch 3: val_accuracy did not improve from 0.28571
# 108/108 [==============================] - 1s 9ms/step - loss: 1.1578 - accuracy: 0.5140 - val_loss: 1.1833 - val_accuracy: 0.2857
# Epoch 4/100
# 107/108 [============================>.] - ETA: 0s - loss: 1.0968 - accuracy: 0.5654
# Epoch 4: val_accuracy did not improve from 0.28571
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0956 - accuracy: 0.5674 - val_loss: 1.2042 - val_accuracy: 0.2857
# Epoch 5/100
# 102/108 [===========================>..] - ETA: 0s - loss: 1.0916 - accuracy: 0.5515
# Epoch 5: val_accuracy did not improve from 0.28571
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0890 - accuracy: 0.5651 - val_loss: 1.2202 - val_accuracy: 0.2857
# Epoch 6/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.1639 - accuracy: 0.4009
# Epoch 6: val_accuracy improved from 0.28571 to 0.30000, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.1630 - accuracy: 0.4023 - val_loss: 1.1883 - val_accuracy: 0.3000
# Epoch 7/100
# 108/108 [==============================] - ETA: 0s - loss: 1.1220 - accuracy: 0.4535
# Epoch 7: val_accuracy improved from 0.30000 to 0.31429, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.1220 - accuracy: 0.4535 - val_loss: 1.1867 - val_accuracy: 0.3143
# Epoch 8/100
# 102/108 [===========================>..] - ETA: 0s - loss: 1.0833 - accuracy: 0.5221
# Epoch 8: val_accuracy improved from 0.31429 to 0.32857, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0800 - accuracy: 0.5372 - val_loss: 1.1787 - val_accuracy: 0.3286
# Epoch 9/100
# 104/108 [===========================>..] - ETA: 0s - loss: 1.0505 - accuracy: 0.5457
# Epoch 9: val_accuracy improved from 0.32857 to 0.37143, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0544 - accuracy: 0.5465 - val_loss: 1.1514 - val_accuracy: 0.3714
# Epoch 10/100
# 104/108 [===========================>..] - ETA: 0s - loss: 1.1675 - accuracy: 0.4591
# Epoch 10: val_accuracy did not improve from 0.37143
# 108/108 [==============================] - 1s 8ms/step - loss: 1.1603 - accuracy: 0.4651 - val_loss: 1.3673 - val_accuracy: 0.2857
# Epoch 11/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.0935 - accuracy: 0.5212
# Epoch 11: val_accuracy improved from 0.37143 to 0.44286, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0928 - accuracy: 0.5233 - val_loss: 1.0953 - val_accuracy: 0.4429
# Epoch 12/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9751 - accuracy: 0.5929
# Epoch 12: val_accuracy did not improve from 0.44286
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9759 - accuracy: 0.5953 - val_loss: 1.0896 - val_accuracy: 0.4286
# Epoch 13/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.0571 - accuracy: 0.5566
# Epoch 13: val_accuracy did not improve from 0.44286
# 108/108 [==============================] - 1s 8ms/step - loss: 1.0555 - accuracy: 0.5605 - val_loss: 1.1622 - val_accuracy: 0.3857
# Epoch 14/100
# 105/108 [============================>.] - ETA: 0s - loss: 1.0591 - accuracy: 0.6333
# Epoch 14: val_accuracy improved from 0.44286 to 0.45714, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0569 - accuracy: 0.6372 - val_loss: 1.0813 - val_accuracy: 0.4571
# Epoch 15/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.9801 - accuracy: 0.5704
# Epoch 15: val_accuracy did not improve from 0.45714
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9772 - accuracy: 0.5791 - val_loss: 1.3924 - val_accuracy: 0.3000
# Epoch 16/100
# 105/108 [============================>.] - ETA: 0s - loss: 1.0655 - accuracy: 0.6214
# Epoch 16: val_accuracy improved from 0.45714 to 0.47143, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0605 - accuracy: 0.6256 - val_loss: 1.0713 - val_accuracy: 0.4714
# Epoch 17/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9598 - accuracy: 0.6238
# Epoch 17: val_accuracy improved from 0.47143 to 0.57143, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9556 - accuracy: 0.6302 - val_loss: 1.0115 - val_accuracy: 0.5714
# Epoch 18/100
# 105/108 [============================>.] - ETA: 0s - loss: 1.0244 - accuracy: 0.5762
# Epoch 18: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0170 - accuracy: 0.5814 - val_loss: 1.0857 - val_accuracy: 0.5000
# Epoch 19/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9739 - accuracy: 0.5896
# Epoch 19: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9741 - accuracy: 0.5907 - val_loss: 1.0779 - val_accuracy: 0.5000
# Epoch 20/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.0240 - accuracy: 0.5778
# Epoch 20: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 1.0232 - accuracy: 0.5767 - val_loss: 1.1561 - val_accuracy: 0.4429
# Epoch 21/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9496 - accuracy: 0.6392
# Epoch 21: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9475 - accuracy: 0.6395 - val_loss: 1.1855 - val_accuracy: 0.4143
# Epoch 22/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.1137 - accuracy: 0.5825
# Epoch 22: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 1.1133 - accuracy: 0.5814 - val_loss: 1.1317 - val_accuracy: 0.4714
# Epoch 23/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.0448 - accuracy: 0.5991
# Epoch 23: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 9ms/step - loss: 1.0427 - accuracy: 0.6000 - val_loss: 1.1556 - val_accuracy: 0.4286
# Epoch 24/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9795 - accuracy: 0.6071
# Epoch 24: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9751 - accuracy: 0.6140 - val_loss: 1.1946 - val_accuracy: 0.4571
# Epoch 25/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9673 - accuracy: 0.5952
# Epoch 25: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9679 - accuracy: 0.5930 - val_loss: 1.1502 - val_accuracy: 0.4857
# Epoch 26/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9772 - accuracy: 0.5991
# Epoch 26: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9774 - accuracy: 0.6000 - val_loss: 1.0757 - val_accuracy: 0.5429
# Epoch 27/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9268 - accuracy: 0.6061
# Epoch 27: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9235 - accuracy: 0.6093 - val_loss: 1.0126 - val_accuracy: 0.5286
# Epoch 28/100
# 106/108 [============================>.] - ETA: 0s - loss: 1.0621 - accuracy: 0.5708
# Epoch 28: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 8ms/step - loss: 1.0597 - accuracy: 0.5744 - val_loss: 1.0485 - val_accuracy: 0.5286
# Epoch 29/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.9225 - accuracy: 0.6466
# Epoch 29: val_accuracy did not improve from 0.57143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9158 - accuracy: 0.6512 - val_loss: 0.9888 - val_accuracy: 0.5286
# Epoch 30/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9141 - accuracy: 0.6509
# Epoch 30: val_accuracy improved from 0.57143 to 0.58571, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9142 - accuracy: 0.6512 - val_loss: 0.9887 - val_accuracy: 0.5857
# Epoch 31/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.8869 - accuracy: 0.6562
# Epoch 31: val_accuracy did not improve from 0.58571
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8916 - accuracy: 0.6535 - val_loss: 1.0674 - val_accuracy: 0.5143
# Epoch 32/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8519 - accuracy: 0.6745
# Epoch 32: val_accuracy did not improve from 0.58571
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8481 - accuracy: 0.6767 - val_loss: 1.1740 - val_accuracy: 0.4714
# Epoch 33/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9122 - accuracy: 0.6429
# Epoch 33: val_accuracy improved from 0.58571 to 0.62857, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9087 - accuracy: 0.6488 - val_loss: 0.9004 - val_accuracy: 0.6286
# Epoch 34/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.8645 - accuracy: 0.6476
# Epoch 34: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8624 - accuracy: 0.6488 - val_loss: 1.1067 - val_accuracy: 0.4714
# Epoch 35/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9401 - accuracy: 0.6595
# Epoch 35: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9316 - accuracy: 0.6651 - val_loss: 0.9566 - val_accuracy: 0.5857
# Epoch 36/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.8727 - accuracy: 0.6619
# Epoch 36: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8714 - accuracy: 0.6674 - val_loss: 1.2008 - val_accuracy: 0.4429
# Epoch 37/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.8697 - accuracy: 0.6357
# Epoch 37: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8728 - accuracy: 0.6372 - val_loss: 1.2280 - val_accuracy: 0.4857
# Epoch 38/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8236 - accuracy: 0.6627
# Epoch 38: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8168 - accuracy: 0.6674 - val_loss: 1.0701 - val_accuracy: 0.5857
# Epoch 39/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.8706 - accuracy: 0.6476
# Epoch 39: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8709 - accuracy: 0.6465 - val_loss: 0.9551 - val_accuracy: 0.5857
# Epoch 40/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.9288 - accuracy: 0.6392
# Epoch 40: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.9265 - accuracy: 0.6419 - val_loss: 1.0393 - val_accuracy: 0.5429
# Epoch 41/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8338 - accuracy: 0.6722
# Epoch 41: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8332 - accuracy: 0.6721 - val_loss: 1.1339 - val_accuracy: 0.4714
# Epoch 42/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.9150 - accuracy: 0.6405
# Epoch 42: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.9084 - accuracy: 0.6465 - val_loss: 1.0124 - val_accuracy: 0.5429
# Epoch 43/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8449 - accuracy: 0.6745
# Epoch 43: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8455 - accuracy: 0.6744 - val_loss: 0.9846 - val_accuracy: 0.5714
# Epoch 44/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8550 - accuracy: 0.6769
# Epoch 44: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8535 - accuracy: 0.6791 - val_loss: 0.9076 - val_accuracy: 0.6143
# Epoch 45/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8054 - accuracy: 0.6840
# Epoch 45: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8048 - accuracy: 0.6860 - val_loss: 0.9866 - val_accuracy: 0.6000
# Epoch 46/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.8130 - accuracy: 0.6779
# Epoch 46: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8091 - accuracy: 0.6837 - val_loss: 1.1449 - val_accuracy: 0.5429
# Epoch 47/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.8160 - accuracy: 0.6792
# Epoch 47: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8139 - accuracy: 0.6814 - val_loss: 0.9532 - val_accuracy: 0.5857
# Epoch 48/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.8116 - accuracy: 0.6923
# Epoch 48: val_accuracy did not improve from 0.62857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8020 - accuracy: 0.7000 - val_loss: 1.1534 - val_accuracy: 0.5571
# Epoch 49/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.7543 - accuracy: 0.7212
# Epoch 49: val_accuracy improved from 0.62857 to 0.71429, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7518 - accuracy: 0.7256 - val_loss: 0.8119 - val_accuracy: 0.7143
# Epoch 50/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.8314 - accuracy: 0.7212
# Epoch 50: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.8266 - accuracy: 0.7233 - val_loss: 0.9723 - val_accuracy: 0.5571
# Epoch 51/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.7662 - accuracy: 0.7071
# Epoch 51: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 8ms/step - loss: 0.7618 - accuracy: 0.7116 - val_loss: 1.0945 - val_accuracy: 0.5429
# Epoch 52/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.7482 - accuracy: 0.7241
# Epoch 52: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 8ms/step - loss: 0.7563 - accuracy: 0.7233 - val_loss: 0.9470 - val_accuracy: 0.6429
# Epoch 53/100
# 102/108 [===========================>..] - ETA: 0s - loss: 0.7507 - accuracy: 0.7279
# Epoch 53: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7328 - accuracy: 0.7395 - val_loss: 1.0767 - val_accuracy: 0.5000
# Epoch 54/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.7908 - accuracy: 0.7143
# Epoch 54: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 8ms/step - loss: 0.7821 - accuracy: 0.7186 - val_loss: 0.9673 - val_accuracy: 0.6143
# Epoch 55/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.7413 - accuracy: 0.7288
# Epoch 55: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7344 - accuracy: 0.7326 - val_loss: 1.3354 - val_accuracy: 0.4714
# Epoch 56/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.7869 - accuracy: 0.7188
# Epoch 56: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7801 - accuracy: 0.7256 - val_loss: 0.9066 - val_accuracy: 0.6286
# Epoch 57/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.7542 - accuracy: 0.7286
# Epoch 57: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7493 - accuracy: 0.7326 - val_loss: 1.2118 - val_accuracy: 0.6143
# Epoch 58/100
# 107/108 [============================>.] - ETA: 0s - loss: 0.7671 - accuracy: 0.7336
# Epoch 58: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7645 - accuracy: 0.7349 - val_loss: 1.1307 - val_accuracy: 0.5571
# Epoch 59/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.7454 - accuracy: 0.7087
# Epoch 59: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7416 - accuracy: 0.7140 - val_loss: 0.9455 - val_accuracy: 0.6429
# Epoch 60/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.7167 - accuracy: 0.7692
# Epoch 60: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 10ms/step - loss: 0.7160 - accuracy: 0.7674 - val_loss: 1.0399 - val_accuracy: 0.6000
# Epoch 61/100
# 107/108 [============================>.] - ETA: 0s - loss: 0.6477 - accuracy: 0.7991
# Epoch 61: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6461 - accuracy: 0.8000 - val_loss: 1.0293 - val_accuracy: 0.6143
# Epoch 62/100
# 107/108 [============================>.] - ETA: 0s - loss: 0.6638 - accuracy: 0.7921
# Epoch 62: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6650 - accuracy: 0.7907 - val_loss: 0.7672 - val_accuracy: 0.7000
# Epoch 63/100
# 107/108 [============================>.] - ETA: 0s - loss: 0.7031 - accuracy: 0.7687
# Epoch 63: val_accuracy did not improve from 0.71429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7044 - accuracy: 0.7674 - val_loss: 0.8736 - val_accuracy: 0.7143
# Epoch 64/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.6787 - accuracy: 0.7812
# Epoch 64: val_accuracy improved from 0.71429 to 0.72857, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6780 - accuracy: 0.7837 - val_loss: 0.7468 - val_accuracy: 0.7286
# Epoch 65/100
# 107/108 [============================>.] - ETA: 0s - loss: 0.6308 - accuracy: 0.8178
# Epoch 65: val_accuracy did not improve from 0.72857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6308 - accuracy: 0.8163 - val_loss: 0.7889 - val_accuracy: 0.7286
# Epoch 66/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.6256 - accuracy: 0.8167
# Epoch 66: val_accuracy did not improve from 0.72857
# 108/108 [==============================] - 1s 10ms/step - loss: 0.6226 - accuracy: 0.8186 - val_loss: 0.7752 - val_accuracy: 0.7143
# Epoch 67/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.6873 - accuracy: 0.7981
# Epoch 67: val_accuracy did not improve from 0.72857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6823 - accuracy: 0.8023 - val_loss: 0.7158 - val_accuracy: 0.7286
# Epoch 68/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.8093
# Epoch 68: val_accuracy did not improve from 0.72857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5874 - accuracy: 0.8093 - val_loss: 0.8024 - val_accuracy: 0.7143
# Epoch 69/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.6273 - accuracy: 0.8160
# Epoch 69: val_accuracy improved from 0.72857 to 0.78571, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6264 - accuracy: 0.8163 - val_loss: 0.6810 - val_accuracy: 0.7857
# Epoch 70/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.6673 - accuracy: 0.8077
# Epoch 70: val_accuracy improved from 0.78571 to 0.81429, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6603 - accuracy: 0.8140 - val_loss: 0.6582 - val_accuracy: 0.8143
# Epoch 71/100
# 108/108 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.8326
# Epoch 71: val_accuracy did not improve from 0.81429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6181 - accuracy: 0.8326 - val_loss: 0.8402 - val_accuracy: 0.7571
# Epoch 72/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.6230 - accuracy: 0.8286
# Epoch 72: val_accuracy did not improve from 0.81429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.6160 - accuracy: 0.8326 - val_loss: 0.6921 - val_accuracy: 0.7571
# Epoch 73/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.5757 - accuracy: 0.8357
# Epoch 73: val_accuracy did not improve from 0.81429
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5705 - accuracy: 0.8395 - val_loss: 0.7755 - val_accuracy: 0.7286
# Epoch 74/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.5732 - accuracy: 0.8381
# Epoch 74: val_accuracy improved from 0.81429 to 0.82857, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5695 - accuracy: 0.8395 - val_loss: 0.6610 - val_accuracy: 0.8286
# Epoch 75/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.5058 - accuracy: 0.8462
# Epoch 75: val_accuracy did not improve from 0.82857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5168 - accuracy: 0.8442 - val_loss: 0.8027 - val_accuracy: 0.7714
# Epoch 76/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.5280 - accuracy: 0.8495
# Epoch 76: val_accuracy did not improve from 0.82857
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5293 - accuracy: 0.8488 - val_loss: 0.7106 - val_accuracy: 0.7714
# Epoch 77/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.5146 - accuracy: 0.8561
# Epoch 77: val_accuracy improved from 0.82857 to 0.85714, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5137 - accuracy: 0.8558 - val_loss: 0.7065 - val_accuracy: 0.8571
# Epoch 78/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.5197 - accuracy: 0.8462
# Epoch 78: val_accuracy did not improve from 0.85714
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5149 - accuracy: 0.8488 - val_loss: 0.9574 - val_accuracy: 0.7429
# Epoch 79/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.8608
# Epoch 79: val_accuracy did not improve from 0.85714
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5404 - accuracy: 0.8605 - val_loss: 0.8137 - val_accuracy: 0.8000
# Epoch 80/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4522 - accuracy: 0.8857
# Epoch 80: val_accuracy improved from 0.85714 to 0.87143, saving model to 3DCNN_Avacado_PCA_model.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4516 - accuracy: 0.8860 - val_loss: 0.6446 - val_accuracy: 0.8714
# Epoch 81/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.4482 - accuracy: 0.8870
# Epoch 81: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4506 - accuracy: 0.8860 - val_loss: 0.6764 - val_accuracy: 0.8143
# Epoch 82/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.4884 - accuracy: 0.8582
# Epoch 82: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4822 - accuracy: 0.8628 - val_loss: 0.8093 - val_accuracy: 0.8143
# Epoch 83/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4374 - accuracy: 0.8810
# Epoch 83: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4344 - accuracy: 0.8837 - val_loss: 0.8063 - val_accuracy: 0.8000
# Epoch 84/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.4715 - accuracy: 0.8822
# Epoch 84: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.4709 - accuracy: 0.8814 - val_loss: 0.9859 - val_accuracy: 0.8000
# Epoch 85/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.5127 - accuracy: 0.8534
# Epoch 85: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5064 - accuracy: 0.8558 - val_loss: 0.6086 - val_accuracy: 0.8000
# Epoch 86/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.5125 - accuracy: 0.8833
# Epoch 86: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5129 - accuracy: 0.8814 - val_loss: 1.1498 - val_accuracy: 0.7857
# Epoch 87/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.4146 - accuracy: 0.9175
# Epoch 87: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.4158 - accuracy: 0.9163 - val_loss: 0.7673 - val_accuracy: 0.7857
# Epoch 88/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4447 - accuracy: 0.9048
# Epoch 88: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4388 - accuracy: 0.9070 - val_loss: 0.9512 - val_accuracy: 0.8000
# Epoch 89/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4442 - accuracy: 0.8762
# Epoch 89: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4390 - accuracy: 0.8791 - val_loss: 0.7430 - val_accuracy: 0.8286
# Epoch 90/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4597 - accuracy: 0.8905
# Epoch 90: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4548 - accuracy: 0.8930 - val_loss: 0.6523 - val_accuracy: 0.8286
# Epoch 91/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4305 - accuracy: 0.9095
# Epoch 91: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4273 - accuracy: 0.9116 - val_loss: 0.8459 - val_accuracy: 0.8143
# Epoch 92/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.4100 - accuracy: 0.8952
# Epoch 92: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4056 - accuracy: 0.8977 - val_loss: 0.9104 - val_accuracy: 0.8143
# Epoch 93/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.3855 - accuracy: 0.9095
# Epoch 93: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.3859 - accuracy: 0.9070 - val_loss: 0.8410 - val_accuracy: 0.8000
# Epoch 94/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.3993 - accuracy: 0.9150
# Epoch 94: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.3969 - accuracy: 0.9163 - val_loss: 0.9247 - val_accuracy: 0.7857
# Epoch 95/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.5754 - accuracy: 0.8726
# Epoch 95: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.5711 - accuracy: 0.8744 - val_loss: 0.7789 - val_accuracy: 0.8571
# Epoch 96/100
# 104/108 [===========================>..] - ETA: 0s - loss: 0.5586 - accuracy: 0.8654
# Epoch 96: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5495 - accuracy: 0.8698 - val_loss: 0.8388 - val_accuracy: 0.7857
# Epoch 97/100
# 105/108 [============================>.] - ETA: 0s - loss: 0.5033 - accuracy: 0.8929
# Epoch 97: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5000 - accuracy: 0.8953 - val_loss: 1.1271 - val_accuracy: 0.7286
# Epoch 98/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.5244 - accuracy: 0.8641
# Epoch 98: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.5148 - accuracy: 0.8698 - val_loss: 0.8284 - val_accuracy: 0.8143
# Epoch 99/100
# 103/108 [===========================>..] - ETA: 0s - loss: 0.4502 - accuracy: 0.9126
# Epoch 99: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4471 - accuracy: 0.9140 - val_loss: 0.7989 - val_accuracy: 0.8000
# Epoch 100/100
# 106/108 [============================>.] - ETA: 0s - loss: 0.4366 - accuracy: 0.9104
# Epoch 100: val_accuracy did not improve from 0.87143
# 108/108 [==============================] - 1s 8ms/step - loss: 0.4396 - accuracy: 0.9093 - val_loss: 0.9172 - val_accuracy: 0.8000

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 20/20 [==============================] - 0s 2ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.55      0.50        20
#            1       0.57      0.53      0.55        40
#            2       0.37      0.35      0.36        20
#
#     accuracy                           0.49        80
#    macro avg       0.46      0.48      0.47        80
# weighted avg       0.49      0.49      0.49        80

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(2)], yticklabels=[str(i) for i in range(2)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
