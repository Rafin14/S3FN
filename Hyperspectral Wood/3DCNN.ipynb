# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
physical_devices = tf.config.experimental.list_physical_devices('GPU')

print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_12888\3036340341.py:4: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data_train = np.load('Wood_train.npy', allow_pickle= True)
data_test = np.load('Wood_test.npy', allow_pickle= True)

train_labels = np.load('Wood_train_labels.npy', allow_pickle= True)
test_labels = np.load('Wood_test_labels.npy', allow_pickle= True)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((264, 32, 32, 320), (264,), (132, 32, 32, 320), (132,))

# %%
mean = data_train.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data_train.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data_train = (data_train - mean) / std_dev

data_test = (data_test - mean) / std_dev

print("Train Shape:", data_train.shape)
print("Test Shape:", data_test.shape)
# Out:
# Train Shape: (264, 32, 32, 320)
# Test Shape: (132, 32, 32, 320)

# %%
hsi_image_train = data_train
hsi_image_test = data_test

hsi_reshaped_train = hsi_image_train.reshape(-1, 320)
hsi_reshaped_test = hsi_image_test.reshape(-1, 320)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((270336, 320), (135168, 320))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.99) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 199
# ((270336, 199), (135168, 199))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(264, 32, 32, optimal_components)
data_test = X_test_pca.reshape(132, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199), (132, 32, 32, 199))

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199, 1), (132, 32, 32, 199, 1))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
def augment_data(sample, label):
    
    # Random flip along different axes
    sample = tf.image.random_flip_left_right(sample)
    sample = tf.image.random_flip_up_down(sample)

    # Random rotation
    sample = tf.image.rot90(sample, k=np.random.randint(1, 4))  # k=1 to 3 random rotations of 90°

    # Random intensity scaling (brightness variation)
    sample = sample * tf.random.uniform([], 0.9, 1.1)  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
tf.random.set_seed(1234)

input_shape = (32, 32, 199, 1)

model = models.Sequential([
    
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3
     
     
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    #layers.BatchNormalization(),
    
    
    
    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3


    layers.Flatten(),
    
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    #layers.BatchNormalization(),
    
    
    
    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    
    
    layers.Dense(2, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 197, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 98, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 96, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 94, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 47, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 150400)            0
#
#  dense (Dense)               (None, 128)               19251328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 19,537,282
# Trainable params: 19,537,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_test.h5',    
    monitor = 'accuracy',          
    save_best_only = True,              
    save_weights_only = False,             
    mode = 'max',                          
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 13.4330 - accuracy: 0.6591
# Epoch 1: accuracy improved from -inf to 0.65909, saving model to best_model_test.h5
# 33/33 [==============================] - 16s 148ms/step - loss: 13.4330 - accuracy: 0.6591 - val_loss: 1.1150 - val_accuracy: 0.5000
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 1.1549 - accuracy: 0.4735
# Epoch 2: accuracy did not improve from 0.65909
# 33/33 [==============================] - 4s 131ms/step - loss: 1.1549 - accuracy: 0.4735 - val_loss: 1.0544 - val_accuracy: 0.5000
# Epoch 3/100
100
# 33/33 [==============================] - ETA: 0s - loss: 0.3423 - accuracy: 0.9167
# Epoch 39: accuracy did not improve from 0.95076
# 33/33 [==============================] - 4s 133ms/step - loss: 0.3423 - accuracy: 0.9167 - val_loss: 0.8206 - val_accuracy: 0.8864
# Epoch 40/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.9394
# Epoch 40: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2680 - accuracy: 0.9394 - val_loss: 1.3154 - val_accuracy: 0.9167
# Epoch 41/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3523 - accuracy: 0.9129
# Epoch 41: accuracy did not improve from 0.95076
# 33/33 [==============================] - 4s 133ms/step - loss: 0.3523 - accuracy: 0.9129 - val_loss: 1.1052 - val_accuracy: 0.9015
# Epoch 42/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.9242
# Epoch 42: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 135ms/step - loss: 0.3077 - accuracy: 0.9242 - val_loss: 1.0434 - val_accuracy: 0.9242
# Epoch 43/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.9394
# Epoch 43: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2921 - accuracy: 0.9394 - val_loss: 1.4073 - val_accuracy: 0.9167
# Epoch 44/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9508
# Epoch 44: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2534 - accuracy: 0.9508 - val_loss: 1.5051 - val_accuracy: 0.9015
# Epoch 45/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.9545
# Epoch 45: accuracy improved from 0.95076 to 0.95455, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2814 - accuracy: 0.9545 - val_loss: 1.4214 - val_accuracy: 0.8864
# Epoch 46/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9735
# Epoch 46: accuracy improved from 0.95455 to 0.97348, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1956 - accuracy: 0.9735 - val_loss: 1.8436 - val_accuracy: 0.8864
# Epoch 47/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.9583
# Epoch 47: accuracy did not improve from 0.97348
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2653 - accuracy: 0.9583 - val_loss: 1.1571 - val_accuracy: 0.9015
# Epoch 48/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9508
# Epoch 48: accuracy did not improve from 0.97348
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2433 - accuracy: 0.9508 - val_loss: 1.6536 - val_accuracy: 0.9015
# Epoch 49/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9811
# Epoch 49: accuracy improved from 0.97348 to 0.98106, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1878 - accuracy: 0.9811 - val_loss: 1.9799 - val_accuracy: 0.8939
# Epoch 50/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9773
# Epoch 50: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2148 - accuracy: 0.9773 - val_loss: 2.5882 - val_accuracy: 0.8788
# Epoch 51/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.9697
# Epoch 51: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2691 - accuracy: 0.9697 - val_loss: 1.0868 - val_accuracy: 0.9015
# Epoch 52/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9545
# Epoch 52: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2670 - accuracy: 0.9545 - val_loss: 1.4958 - val_accuracy: 0.8864
# Epoch 53/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9697
# Epoch 53: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2213 - accuracy: 0.9697 - val_loss: 1.6381 - val_accuracy: 0.8788
# Epoch 54/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.9583
# Epoch 54: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2953 - accuracy: 0.9583 - val_loss: 1.4904 - val_accuracy: 0.8864
# Epoch 55/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9659
# Epoch 55: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2203 - accuracy: 0.9659 - val_loss: 1.6531 - val_accuracy: 0.8712
# Epoch 56/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9697
# Epoch 56: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2155 - accuracy: 0.9697 - val_loss: 2.2843 - val_accuracy: 0.8939
# Epoch 57/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.9470
# Epoch 57: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.3487 - accuracy: 0.9470 - val_loss: 1.4194 - val_accuracy: 0.8712
# Epoch 58/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.9394
# Epoch 58: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.3114 - accuracy: 0.9394 - val_loss: 1.5863 - val_accuracy: 0.8561
# Epoch 59/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.9129
# Epoch 59: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.3461 - accuracy: 0.9129 - val_loss: 1.7841 - val_accuracy: 0.8712
# Epoch 60/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9659
# Epoch 60: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2249 - accuracy: 0.9659 - val_loss: 2.3035 - val_accuracy: 0.8788
# Epoch 61/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9773
# Epoch 61: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2251 - accuracy: 0.9773 - val_loss: 2.1452 - val_accuracy: 0.8712
# Epoch 62/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9773
# Epoch 62: accuracy did not improve from 0.98106
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2379 - accuracy: 0.9773 - val_loss: 2.1293 - val_accuracy: 0.8864
# Epoch 63/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9848
# Epoch 63: accuracy improved from 0.98106 to 0.98485, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 145ms/step - loss: 0.1822 - accuracy: 0.9848 - val_loss: 2.1005 - val_accuracy: 0.8788
# Epoch 64/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9545
# Epoch 64: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2243 - accuracy: 0.9545 - val_loss: 1.7633 - val_accuracy: 0.8712
# Epoch 65/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2040 - accuracy: 0.9773
# Epoch 65: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 134ms/step - loss: 0.2040 - accuracy: 0.9773 - val_loss: 2.4656 - val_accuracy: 0.8712
# Epoch 66/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9735
# Epoch 66: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.1957 - accuracy: 0.9735 - val_loss: 2.4319 - val_accuracy: 0.8864
# Epoch 67/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9811
# Epoch 67: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 136ms/step - loss: 0.1944 - accuracy: 0.9811 - val_loss: 2.1661 - val_accuracy: 0.8939
# Epoch 68/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9811
# Epoch 68: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.1825 - accuracy: 0.9811 - val_loss: 2.5365 - val_accuracy: 0.8788
# Epoch 69/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9811
# Epoch 69: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2065 - accuracy: 0.9811 - val_loss: 1.8771 - val_accuracy: 0.8864
# Epoch 70/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9621
# Epoch 70: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2310 - accuracy: 0.9621 - val_loss: 2.3922 - val_accuracy: 0.8788
# Epoch 71/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9773
# Epoch 71: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 136ms/step - loss: 0.2084 - accuracy: 0.9773 - val_loss: 2.7041 - val_accuracy: 0.8636
# Epoch 72/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9735
# Epoch 72: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2155 - accuracy: 0.9735 - val_loss: 1.5346 - val_accuracy: 0.8864
# Epoch 73/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9545
# Epoch 73: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2572 - accuracy: 0.9545 - val_loss: 2.5462 - val_accuracy: 0.8788
# Epoch 74/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9735
# Epoch 74: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2034 - accuracy: 0.9735 - val_loss: 2.9802 - val_accuracy: 0.8561
# Epoch 75/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2271 - accuracy: 0.9659
# Epoch 75: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2271 - accuracy: 0.9659 - val_loss: 1.5123 - val_accuracy: 0.8636
# Epoch 76/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9811
# Epoch 76: accuracy did not improve from 0.98485
# 33/33 [==============================] - 5s 135ms/step - loss: 0.2258 - accuracy: 0.9811 - val_loss: 2.0366 - val_accuracy: 0.8636
# Epoch 77/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9886
# Epoch 77: accuracy improved from 0.98485 to 0.98864, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 143ms/step - loss: 0.1989 - accuracy: 0.9886 - val_loss: 2.2172 - val_accuracy: 0.8788
# Epoch 78/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9848
# Epoch 78: accuracy did not improve from 0.98864
# 33/33 [==============================] - 5s 136ms/step - loss: 0.2433 - accuracy: 0.9848 - val_loss: 1.7140 - val_accuracy: 0.8864

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 17/17 [==============================] - 1s 34ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        66
#            1       0.88      0.88      0.88        66
#
#     accuracy                           0.88       132
#    macro avg       0.88      0.88      0.88       132
# weighted avg       0.88      0.88      0.88       132

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(2)], yticklabels=[str(i) for i in range(2)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
