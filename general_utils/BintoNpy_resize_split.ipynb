# %%
import os
import shutil
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
from skimage.transform import resize
import random

# %%
ENVI_TO_NP = {
    1: np.uint8,
    2: np.int16,
    3: np.int32,
    4: np.float32,
    5: np.float64,
    12: np.uint16,
    13: np.uint32,
    14: np.int64,
    15: np.uint64
}

# Cell 2: Utility Functions
def parse_envi_header(hdr_path):
    """Parse ENVI header file into a dictionary"""
    header = {}
    with open(hdr_path, 'r') as f:
        for line in f:
            line = line.strip()
            if '=' in line:
                key, value = line.split('=', 1)
                key = key.strip().lower()
                value = value.strip()
                header[key] = value
    return header

def get_file_list(input_root):
    """Find all .bin files in directory structure"""
    bin_files = []
    for root, dirs, files in os.walk(input_root):
        for file in files:
            if file.endswith('.bin'):
                bin_files.append(os.path.join(root, file))
    return bin_files

# Cell 3: Processing Functions
def process_hsi_file(bin_path, output_root):
    """Process a single HSI file and return statistics"""
    hdr_path = os.path.splitext(bin_path)[0] + '.hdr'
    if not os.path.exists(hdr_path):
        raise FileNotFoundError(f"No header file found for {bin_path}")

    header = parse_envi_header(hdr_path)
    
    height = int(header['lines'])
    width = int(header['samples'])
    bands = int(header['bands'])
    dtype = ENVI_TO_NP[int(header['data type'])]
    interleave = header.get('interleave', 'bil').lower()
    byte_order = '<' if int(header.get('byte order', 0)) == 0 else '>'
    dtype = np.dtype(dtype).newbyteorder(byte_order)

    with open(bin_path, 'rb') as f:
        data = np.fromfile(f, dtype=dtype)
    
    if interleave == 'bil':
        data = data.reshape((height, bands, width)).transpose(0, 2, 1)
    elif interleave == 'bip':
        data = data.reshape((height, width, bands))
    elif interleave == 'bsq':
        data = data.reshape((bands, height, width)).transpose(1, 2, 0)
    else:
        raise ValueError(f"Unsupported interleave format: {interleave}")

    # Save to npy
    rel_path = os.path.splitext(os.path.relpath(bin_path, input_root))[0]
    output_path = os.path.join(output_root, rel_path + '.npy')
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    np.save(output_path, data)

    return {
        'height': height,
        'width': width,
        'bands': bands,
        'pixel_min': np.min(data),
        'pixel_max': np.max(data),
        'pixel_sum': np.sum(data),
        'pixel_count': data.size
    }

# Cell 4: Main Processing and Statistics
def process_all_files(input_root, output_root):
    """Process all files and collect statistics"""
    file_list = get_file_list(input_root)
    all_stats = []
    global_stats = {
        'total_pixel_sum': 0,
        'total_pixel_count': 0,
        'global_pixel_min': None,
        'global_pixel_max': None,
        'dim_stats': defaultdict(list)
    }
    
    for i, bin_path in enumerate(file_list):
        try:
            print(f"Processing {i+1}/{len(file_list)}: {bin_path}")
            stats = process_hsi_file(bin_path, output_root)
            all_stats.append(stats)
            
            # Update global statistics
            global_stats['total_pixel_sum'] += stats['pixel_sum']
            global_stats['total_pixel_count'] += stats['pixel_count']
            
            if (global_stats['global_pixel_min'] is None or 
                stats['pixel_min'] < global_stats['global_pixel_min']):
                global_stats['global_pixel_min'] = stats['pixel_min']
            
            if (global_stats['global_pixel_max'] is None or 
                stats['pixel_max'] > global_stats['global_pixel_max']):
                global_stats['global_pixel_max'] = stats['pixel_max']
            
            # Update dimension stats
            for dim in ['height', 'width', 'bands']:
                global_stats['dim_stats'][dim].append(stats[dim])
                
        except Exception as e:
            print(f"Error processing {bin_path}: {str(e)}")
            continue
    
    return global_stats, all_stats

# Cell 5: Visualization and Reporting
def print_statistics(global_stats):
    """Print formatted statistics"""
    print("Dimension Statistics:")
    for dim in ['height', 'width', 'bands']:
        values = global_stats['dim_stats'][dim]
        print(f"{dim.capitalize()}:")
        print(f"  Min: {min(values)}")
        print(f"  Max: {max(values)}")
        print(f"  Avg: {sum(values)/len(values):.2f}")
    
    print("\nPixel Value Statistics:")
    print(f"Global Minimum: {global_stats['global_pixel_min']}")
    print(f"Global Maximum: {global_stats['global_pixel_max']}")
    if global_stats['total_pixel_count'] > 0:
        print(f"Global Mean: {global_stats['total_pixel_sum'] / global_stats['total_pixel_count']:.4f}")

def plot_dimension_distributions(global_stats):
    """Plot histograms for dimensions"""
    fig, axs = plt.subplots(1, 3, figsize=(15, 4))
    for i, dim in enumerate(['height', 'width', 'bands']):
        axs[i].hist(global_stats['dim_stats'][dim], bins=20, alpha=0.7)
        axs[i].set_title(f'{dim.capitalize()} Distribution')
        axs[i].set_xlabel(dim)
        axs[i].set_ylabel('Count')
    plt.tight_layout()
    plt.show()

# %%
# Cell 6: Execution Cell (Edit paths here before running)
if __name__ == "__main__":
    
    # Set your paths here
    input_root = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness'
    output_root = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy'
    
    # Process files and get statistics
    global_stats, all_stats = process_all_files(input_root, output_root)
    
    # Print statistics
    print_statistics(global_stats)
    
    # Show visualizations
    plot_dimension_distributions(global_stats)
# Out:
# Processing 1/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_02_33_back.bin
# Processing 2/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_02_33_front.bin
# Processing 3/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_03_07_back.bin
# Processing 4/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_03_07_front.bin
# Processing 5/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_04_13_back.bin
# Processing 6/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_04_13_front.bin
# Processing 7/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_04_22_back.bin
# Processing 8/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_04_22_front.bin
# Processing 9/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_06_20_back.bin
# Processing 10/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_06_20_front.bin
# Processing 11/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_09_back.bin
# Processing 12/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_09_front.bin
# Processing 13/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_14_back.bin
# Processing 14/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_14_front.bin
# Processing 15/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_16_back.bin
# Processing 16/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_07_16_front.bin
# Processing 17/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_08_04_back.bin
# Processing 18/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_08_04_front.bin
# Processing 19/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_10_27_back.bin
# Processing 20/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Overripe\kiwi_day_10_27_front.bin
# Processing 21/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_01_03_back.bin
# Processing 22/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_01_03_front.bin
# Processing 23/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_01_28_back.bin
# Processing 24/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_01_28_front.bin
# Processing 25/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_02_10_back.bin
# Processing 26/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_02_10_front.bin
# Processing 27/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_02_15_back.bin
# Processing 28/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_02_15_front.bin
# Processing 29/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_03_17_back.bin
# Processing 30/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_03_17_front.bin
# Processing 31/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_03_23_back.bin
# Processing 32/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_03_23_front.bin
# Processing 33/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_12_back.bin
# Processing 34/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_12_front.bin
# Processing 35/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_21_back.bin
# Processing 36/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_21_front.bin
# Processing 37/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_29_back.bin
# Processing 38/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_04_29_front.bin
# Processing 39/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_02_back.bin
# Processing 40/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_02_front.bin
# Processing 41/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_05_back.bin
# Processing 42/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_05_front.bin
# Processing 43/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_08_back.bin
# Processing 44/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_05_08_front.bin
# Processing 45/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_01_back.bin
# Processing 46/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_01_front.bin
# Processing 47/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_11_back.bin
# Processing 48/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_11_front.bin
# Processing 49/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_35_back.bin
# Processing 50/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_35_front.bin
# Processing 51/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_36_back.bin
# Processing 52/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_36_front.bin
# Processing 53/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_38_back.bin
# Processing 54/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_06_38_front.bin
# Processing 55/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_07_06_back.bin
# Processing 56/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_07_06_front.bin
# Processing 57/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_09_25_back.bin
# Processing 58/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Perfect\kiwi_day_09_25_front.bin
# Processing 59/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_02_30_back.bin
# Processing 60/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_02_30_front.bin
# Processing 61/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_02_31_back.bin
# Processing 62/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_02_31_front.bin
# Processing 63/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_03_19_back.bin
# Processing 64/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_03_19_front.bin
# Processing 65/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_03_39_back.bin
# Processing 66/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_03_39_front.bin
# Processing 67/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_04_18_back.bin
# Processing 68/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_04_18_front.bin
# Processing 69/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_26_back.bin
# Processing 70/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_26_front.bin
# Processing 71/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_32_back.bin
# Processing 72/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_32_front.bin
# Processing 73/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_37_back.bin
# Processing 74/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_05_37_front.bin
# Processing 75/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_07_24_back.bin
# Processing 76/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\NIR\Unripe\kiwi_day_07_24_front.bin
# Processing 77/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_02_33_back.bin
# Processing 78/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_02_33_front.bin
# Processing 79/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_03_07_back.bin
# Processing 80/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_03_07_front.bin
# Processing 81/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_04_13_back.bin
# Processing 82/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_04_13_front.bin
# Processing 83/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_04_22_back.bin
# Processing 84/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_04_22_front.bin
# Processing 85/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_06_20_back.bin
# Processing 86/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_06_20_front.bin
# Processing 87/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_09_back.bin
# Processing 88/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_09_front.bin
# Processing 89/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_14_back.bin
# Processing 90/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_14_front.bin
# Processing 91/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_16_back.bin
# Processing 92/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_07_16_front.bin
# Processing 93/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_08_04_back.bin
# Processing 94/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_08_04_front.bin
# Processing 95/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_10_27_back.bin
# Processing 96/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_10_27_front.bin
# Processing 97/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_01_62_back.bin
# Processing 98/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_01_62_front.bin
# Processing 99/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_01_75_back.bin
# Processing 100/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_01_75_front.bin
# Processing 101/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_02_75_back.bin
# Processing 102/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_02_75_front.bin
# Processing 103/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_03_75_back.bin
# Processing 104/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_03_75_front.bin
# Processing 105/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_04_75_back.bin
# Processing 106/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_04_75_front.bin
# Processing 107/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_05_75_back.bin
# Processing 108/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_05_75_front.bin
# Processing 109/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_08_63_back.bin
# Processing 110/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_08_63_front.bin
# Processing 111/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_11_68_back.bin
# Processing 112/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_11_68_front.bin
# Processing 113/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_13_64_back.bin
# Processing 114/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_13_64_front.bin
# Processing 115/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_14_48_back.bin
# Processing 116/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_14_48_front.bin
# Processing 117/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_15_45_back.bin
# Processing 118/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_15_45_front.bin
# Processing 119/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_15_48_back.bin
# Processing 120/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_15_48_front.bin
# Processing 121/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_16_48_back.bin
# Processing 122/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_16_48_front.bin
# Processing 123/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_17_48_back.bin
# Processing 124/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Overripe\kiwi_day_m2_17_48_front.bin
# Processing 125/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_01_03_back.bin
# Processing 126/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_01_03_front.bin
# Processing 127/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_01_28_back.bin
# Processing 128/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_01_28_front.bin
# Processing 129/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_02_10_back.bin
# Processing 130/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_02_10_front.bin
# Processing 131/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_02_15_back.bin
# Processing 132/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_02_15_front.bin
# Processing 133/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_03_17_back.bin
# Processing 134/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_03_17_front.bin
# Processing 135/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_03_23_back.bin
# Processing 136/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_03_23_front.bin
# Processing 137/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_12_back.bin
# Processing 138/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_12_front.bin
# Processing 139/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_21_back.bin
# Processing 140/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_21_front.bin
# Processing 141/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_29_back.bin
# Processing 142/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_04_29_front.bin
# Processing 143/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_02_back.bin
# Processing 144/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_02_front.bin
# Processing 145/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_05_back.bin
# Processing 146/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_05_front.bin
# Processing 147/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_08_back.bin
# Processing 148/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_05_08_front.bin
# Processing 149/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_01_back.bin
# Processing 150/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_01_front.bin
# Processing 151/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_11_back.bin
# Processing 152/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_11_front.bin
# Processing 153/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_35_back.bin
# Processing 154/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_35_front.bin
# Processing 155/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_36_back.bin
# Processing 156/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_36_front.bin
# Processing 157/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_38_back.bin
# Processing 158/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_06_38_front.bin
# Processing 159/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_07_06_back.bin
# Processing 160/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_07_06_front.bin
# Processing 161/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_09_25_back.bin
# Processing 162/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_09_25_front.bin
# Processing 163/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_02_43_back.bin
# Processing 164/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_02_43_front.bin
# Processing 165/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_40_back.bin
# Processing 166/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_40_front.bin
# Processing 167/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_52_back.bin
# Processing 168/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_52_front.bin
# Processing 169/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_77_back.bin
# Processing 170/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_03_77_front.bin
# Processing 171/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_04_81_back.bin
# Processing 172/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_04_81_front.bin
# Processing 173/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_04_87_back.bin
# Processing 174/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_04_87_front.bin
# Processing 175/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_05_65_back.bin
# Processing 176/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_05_65_front.bin
# Processing 177/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_78_back.bin
# Processing 178/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_78_front.bin
# Processing 179/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_79_back.bin
# Processing 180/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_79_front.bin
# Processing 181/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_86_back.bin
# Processing 182/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_06_86_front.bin
# Processing 183/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_49_back.bin
# Processing 184/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_49_front.bin
# Processing 185/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_56_back.bin
# Processing 186/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_56_front.bin
# Processing 187/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_60_back.bin
# Processing 188/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_07_60_front.bin
# Processing 189/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_08_82_back.bin
# Processing 190/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_08_82_front.bin
# Processing 191/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_09_47_back.bin
# Processing 192/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_09_47_front.bin
# Processing 193/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_10_58_back.bin
# Processing 194/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_10_58_front.bin
# Processing 195/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_11_66_back.bin
# Processing 196/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_11_66_front.bin
# Processing 197/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_11_73_back.bin
# Processing 198/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_11_73_front.bin
# Processing 199/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_13_42_back.bin
# Processing 200/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_13_42_front.bin
# Processing 201/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_16_50_back.bin
# Processing 202/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_16_50_front.bin
# Processing 203/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_16_57_back.bin
# Processing 204/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Perfect\kiwi_day_m2_16_57_front.bin
# Processing 205/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_02_30_back.bin
# Processing 206/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_02_30_front.bin
# Processing 207/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_02_31_back.bin
# Processing 208/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_02_31_front.bin
# Processing 209/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_03_19_back.bin
# Processing 210/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_03_19_front.bin
# Processing 211/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_03_39_back.bin
# Processing 212/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_03_39_front.bin
# Processing 213/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_04_18_back.bin
# Processing 214/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_04_18_front.bin
# Processing 215/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_26_back.bin
# Processing 216/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_26_front.bin
# Processing 217/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_32_back.bin
# Processing 218/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_32_front.bin
# Processing 219/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_37_back.bin
# Processing 220/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_05_37_front.bin
# Processing 221/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_07_24_back.bin
# Processing 222/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_07_24_front.bin
# Processing 223/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_01_53_back.bin
# Processing 224/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_01_53_front.bin
# Processing 225/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_01_71_back.bin
# Processing 226/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_01_71_front.bin
# Processing 227/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_02_85_back.bin
# Processing 228/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_02_85_front.bin
# Processing 229/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_03_70_back.bin
# Processing 230/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_03_70_front.bin
# Processing 231/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_04_61_back.bin
# Processing 232/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_04_61_front.bin
# Processing 233/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_04_72_back.bin
# Processing 234/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_04_72_front.bin
# Processing 235/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_05_51_back.bin
# Processing 236/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_05_51_front.bin
# Processing 237/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_05_74_back.bin
# Processing 238/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_05_74_front.bin
# Processing 239/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_06_84_back.bin
# Processing 240/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_06_84_front.bin
# Processing 241/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_07_83_back.bin
# Processing 242/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_07_83_front.bin
# Processing 243/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_08_54_back.bin
# Processing 244/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_08_54_front.bin
# Processing 245/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_09_59_back.bin
# Processing 246/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_09_59_front.bin
# Processing 247/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_09_80_back.bin
# Processing 248/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_09_80_front.bin
# Processing 249/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_10_46_back.bin
# Processing 250/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_10_46_front.bin
# Processing 251/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_10_55_back.bin
# Processing 252/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_10_55_front.bin
# Processing 253/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_12_76_back.bin
# Processing 254/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_12_76_front.bin
# Processing 255/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_14_41_back.bin
# Processing 256/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_14_41_front.bin
# Processing 257/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_14_67_back.bin
# Processing 258/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_14_67_front.bin
# Processing 259/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_15_69_back.bin
# Processing 260/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_15_69_front.bin
# Processing 261/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_17_44_back.bin
# Processing 262/262: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness\VIS\Unripe\kiwi_day_m2_17_44_front.bin
# Dimension Statistics:
# Height:
#   Min: 153
#   Max: 331
#   Avg: 237.57
# Width:
#   Min: 73
#   Max: 272
#   Avg: 198.65
# Bands:
#   Min: 224
#   Max: 252
#   Avg: 232.12
#
# Pixel Value Statistics:
# Global Minimum: -96.99404907226562
# Global Maximum: 147.013427734375
# Global Mean: 0.2048

# %%
def compute_stats(values):
    
    """Compute min, max, and average of a list."""
    if not values:
        return None, None, None
    return min(values), max(values), sum(values) / len(values)

def analyze_hsi_dataset(root_dir):
    
    # Initialize lists to store dimensions
    heights = []
    widths = []
    bands_list = []
    
    # Traverse directory structure
    for root, dirs, files in os.walk(root_dir):
        
        for file in files:
            
            if file.endswith('.npy'):
                
                file_path = os.path.join(root, file)
                
                try:
                    arr = np.load(file_path)
                    
                    if arr.ndim != 3:
                        print(f"Skipping {file_path}: Expected 3D array, got {arr.ndim}D")
                        
                        continue
                    
                    # Assuming shape is (height, width, bands)
                    h, w, b = arr.shape  # Adjust indices if your data uses a different order
                    
                    heights.append(h)
                    widths.append(w)
                    bands_list.append(b)
                    
                except Exception as e:
                    print(f"Error processing {file_path}: {str(e)}")
    
    # Compute statistics
    h_min, h_max, h_avg = compute_stats(heights)
    w_min, w_max, w_avg = compute_stats(widths)
    b_min, b_max, b_avg = compute_stats(bands_list)
    
    # Print results
    print("Height Statistics:")
    print(f"  Min: {h_min}, Max: {h_max}, Average: {h_avg:.2f}")
    print("\nWidth Statistics:")
    print(f"  Min: {w_min}, Max: {w_max}, Average: {w_avg:.2f}")
    print("\nBands Statistics:")
    print(f"  Min: {b_min}, Max: {b_max}, Average: {b_avg:.2f}")

if __name__ == "__main__":
    
    root_directory = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS'
    analyze_hsi_dataset(root_directory)
# Out:
# Height Statistics:
#   Min: 205, Max: 331, Average: 256.42
#
# Width Statistics:
#   Min: 174, Max: 272, Average: 214.51
#
# Bands Statistics:
#   Min: 224, Max: 224, Average: 224.00

# %%
def resize_hsi(arr, target_h, target_w, preserve_range=True):
    
    # Initialize resized array
    resized = np.zeros((target_h, target_w, arr.shape[2]), dtype=arr.dtype)
    
    # Resize each band individually
    for band in range(arr.shape[2]):
        resized_band = resize(
            arr[:, :, band],
            (target_h, target_w),
            preserve_range=preserve_range,
            anti_aliasing=True  # Reduces artifacts
        )
        resized[:, :, band] = resized_band
        
    return resized


def process_hsi_dataset(input_root, output_root, target_h, target_w):
    
    for root, dirs, files in os.walk(input_root):
        for file in files:
            if file.endswith('.npy'):
                # Create output directory structure
                rel_path = os.path.relpath(root, input_root)
                output_dir = os.path.join(output_root, rel_path)
                os.makedirs(output_dir, exist_ok=True)
                
                # Process file
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, file)
                
                try:
                    # Load original HSI
                    arr = np.load(input_path)
                    
                    if arr.ndim != 3:
                        print(f"Skipping {input_path}: Not a 3D array")
                        continue
                        
                    # Resize and save
                    resized_arr = resize_hsi(arr, target_h, target_w)
                    np.save(output_path, resized_arr)
                    print(f"Processed: {input_path} -> {output_path}")
                    
                except Exception as e:
                    print(f"Error processing {input_path}: {str(e)}")


if __name__ == "__main__":
    # Configuration
    input_directory = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS'
    output_directory = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized'
    target_height = 250  # Set your desired height
    target_width = 200   # Set your desired width
    
    # Run processing
    process_hsi_dataset(
        input_root=input_directory,
        output_root=output_directory,
        target_h=target_height,
        target_w=target_width
    )
# Out:
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_02_33_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_02_33_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_02_33_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_02_33_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_03_07_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_03_07_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_03_07_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_03_07_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_04_13_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_04_13_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_04_13_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_04_13_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_04_22_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_04_22_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_04_22_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_04_22_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_06_20_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_06_20_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_06_20_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_06_20_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_09_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_09_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_09_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_09_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_14_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_14_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_14_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_14_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_16_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_16_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_07_16_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_07_16_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_08_04_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_08_04_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_08_04_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_08_04_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_10_27_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_10_27_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_10_27_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_10_27_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_01_62_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_01_62_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_01_62_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_01_62_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_01_75_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_01_75_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_01_75_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_01_75_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_02_75_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_02_75_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_02_75_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_02_75_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_03_75_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_03_75_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_03_75_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_03_75_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_04_75_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_04_75_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_04_75_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_04_75_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_05_75_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_05_75_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_05_75_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_05_75_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_08_63_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_08_63_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_08_63_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_08_63_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_11_68_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_11_68_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_11_68_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_11_68_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_13_64_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_13_64_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_13_64_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_13_64_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_14_48_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_14_48_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_14_48_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_14_48_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_15_45_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_15_45_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_15_45_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_15_45_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_15_48_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_15_48_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_15_48_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_15_48_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_16_48_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_16_48_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_16_48_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_16_48_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_17_48_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_17_48_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Overripe\kiwi_day_m2_17_48_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Overripe\kiwi_day_m2_17_48_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_01_03_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_01_03_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_01_03_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_01_03_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_01_28_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_01_28_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_01_28_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_01_28_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_02_10_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_02_10_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_02_10_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_02_10_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_02_15_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_02_15_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_02_15_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_02_15_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_03_17_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_03_17_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_03_17_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_03_17_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_03_23_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_03_23_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_03_23_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_03_23_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_12_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_12_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_12_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_12_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_21_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_21_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_21_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_21_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_29_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_29_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_04_29_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_04_29_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_02_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_02_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_02_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_02_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_05_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_05_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_05_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_05_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_08_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_08_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_05_08_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_05_08_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_01_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_01_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_01_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_01_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_11_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_11_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_11_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_11_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_35_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_35_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_35_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_35_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_36_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_36_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_36_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_36_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_38_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_38_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_06_38_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_06_38_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_07_06_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_07_06_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_07_06_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_07_06_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_09_25_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_09_25_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_09_25_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_09_25_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_02_43_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_02_43_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_02_43_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_02_43_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_40_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_40_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_40_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_40_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_52_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_52_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_52_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_52_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_77_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_77_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_03_77_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_03_77_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_04_81_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_04_81_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_04_81_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_04_81_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_04_87_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_04_87_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_04_87_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_04_87_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_05_65_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_05_65_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_05_65_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_05_65_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_78_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_78_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_78_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_78_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_79_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_79_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_79_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_79_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_86_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_86_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_06_86_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_06_86_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_49_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_49_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_49_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_49_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_56_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_56_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_56_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_56_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_60_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_60_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_07_60_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_07_60_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_08_82_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_08_82_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_08_82_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_08_82_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_09_47_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_09_47_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_09_47_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_09_47_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_10_58_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_10_58_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_10_58_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_10_58_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_11_66_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_11_66_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_11_66_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_11_66_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_11_73_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_11_73_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_11_73_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_11_73_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_13_42_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_13_42_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_13_42_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_13_42_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_16_50_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_16_50_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_16_50_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_16_50_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_16_57_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_16_57_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Perfect\kiwi_day_m2_16_57_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Perfect\kiwi_day_m2_16_57_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_02_30_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_02_30_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_02_30_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_02_30_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_02_31_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_02_31_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_02_31_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_02_31_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_03_19_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_03_19_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_03_19_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_03_19_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_03_39_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_03_39_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_03_39_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_03_39_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_04_18_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_04_18_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_04_18_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_04_18_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_26_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_26_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_26_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_26_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_32_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_32_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_32_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_32_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_37_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_37_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_05_37_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_05_37_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_07_24_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_07_24_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_07_24_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_07_24_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_01_53_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_01_53_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_01_53_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_01_53_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_01_71_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_01_71_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_01_71_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_01_71_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_02_85_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_02_85_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_02_85_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_02_85_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_03_70_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_03_70_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_03_70_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_03_70_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_04_61_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_04_61_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_04_61_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_04_61_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_04_72_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_04_72_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_04_72_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_04_72_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_05_51_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_05_51_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_05_51_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_05_51_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_05_74_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_05_74_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_05_74_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_05_74_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_06_84_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_06_84_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_06_84_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_06_84_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_07_83_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_07_83_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_07_83_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_07_83_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_08_54_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_08_54_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_08_54_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_08_54_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_09_59_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_09_59_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_09_59_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_09_59_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_09_80_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_09_80_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_09_80_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_09_80_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_10_46_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_10_46_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_10_46_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_10_46_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_10_55_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_10_55_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_10_55_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_10_55_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_12_76_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_12_76_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_12_76_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_12_76_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_14_41_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_14_41_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_14_41_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_14_41_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_14_67_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_14_67_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_14_67_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_14_67_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_15_69_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_15_69_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_15_69_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_15_69_front.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_17_44_back.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_17_44_back.npy
# Processed: D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS\Unripe\kiwi_day_m2_17_44_front.npy -> D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized\Unripe\kiwi_day_m2_17_44_front.npy

# %%
def visualize_random_hsi(directory, num_images=4, figsize=(15, 10)):
    # Find all .npy files in directory
    hsi_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.npy'):
                hsi_files.append(os.path.join(root, file))
    
    if not hsi_files:
        print("No .npy files found in directory!")
        return

    # Select random files
    selected_files = random.sample(hsi_files, min(num_images, len(hsi_files)))
    
    # Create subplots
    rows = int(np.sqrt(num_images))
    cols = int(np.ceil(num_images / rows))
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.ravel() if num_images > 1 else [axes]

    for idx, file_path in enumerate(selected_files):
        try:
            # Load HSI cube
            hsi = np.load(file_path)
            
            if hsi.ndim != 3:
                print(f"Skipping {file_path}: Not a 3D array")
                continue

            # Create pseudo-color image (mean across bands)
            img = np.mean(hsi, axis=2)  # Change axis if different dimension order
            
            # Plot with Viridis colormap
            axes[idx].imshow(img, cmap='viridis')
            axes[idx].set_title(os.path.basename(file_path))
            axes[idx].axis('off')

        except Exception as e:
            print(f"Error visualizing {file_path}: {str(e)}")
    
    # Hide empty axes
    for j in range(idx+1, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    output_directory = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\VIS_resized'
    
    visualize_random_hsi(
        
        directory=output_directory,
        num_images=4,        # Number of images to display
        figsize=(15, 10)     # Figure size
    )

# %%
def split_dataset(source_dir, output_dir, train_ratio=0.75, val_ratio=0.125, test_ratio=0.125):
    
    if not os.path.exists(source_dir):
        
        print(f"Source directory '{source_dir}' does not exist.")
        
        return

    # Ensure ratios sum up to 1
    assert train_ratio + val_ratio + test_ratio == 1, "Ratios must sum up to 1"

    # Define output subdirectories
    train_dir = os.path.join(output_dir, "train")
    val_dir = os.path.join(output_dir, "val")
    test_dir = os.path.join(output_dir, "test")

    # Create output directories if they don't exist
    for folder in [train_dir, val_dir, test_dir]:
        os.makedirs(folder, exist_ok=True)

    # Walk through dataset and split files
    for root, dirs, files in os.walk(source_dir):
        if not files:
            continue  # Skip empty directories
        
        # Relative path from source directory
        rel_path = os.path.relpath(root, source_dir)

        # Create corresponding folders in train, val, test
        for subset_dir in [train_dir, val_dir, test_dir]:
            os.makedirs(os.path.join(subset_dir, rel_path), exist_ok=True)

        # Shuffle and split files
        random.shuffle(files)
        total_files = len(files)
        train_split = int(total_files * train_ratio)
        val_split = int(total_files * val_ratio)

        train_files = files[:train_split]
        val_files = files[train_split:train_split + val_split]
        test_files = files[train_split + val_split:]

        # Copy files to respective directories
        for file in train_files:
            shutil.copy2(os.path.join(root, file), os.path.join(train_dir, rel_path, file))
        for file in val_files:
            shutil.copy2(os.path.join(root, file), os.path.join(val_dir, rel_path, file))
        for file in test_files:
            shutil.copy2(os.path.join(root, file), os.path.join(test_dir, rel_path, file))

    print(f"Dataset split complete. Check '{output_dir}' for the split dataset.")

# Example usage
source_dataset = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\NIR_resized'
split_output = r'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\NIR_resized_Split'
split_dataset(source_dataset, split_output)
# Out:
# Dataset split complete. Check 'D:\CSE499A\Datasets\Ripeness\v1\Kiwi_Extract_V1\Ripeness_npy\NIR_resized_Split' for the split dataset.
